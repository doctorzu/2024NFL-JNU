# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# %%
games = pd.read_csv('../../Dataset/games.csv')
players = pd.read_csv('../../Dataset/players.csv')
plays = pd.read_csv('../../Dataset/plays.csv')
tackles = pd.read_csv('../../Dataset/tackles.csv')

files=[]
for i in range(1,10):
    file='../../Dataset/tracking_week_'+str(i)+'.csv'
    files.append(pd.read_csv(file))
    tracking=pd.concat(files)

# %% [markdown]
# 公制化转换

# %%
def metric_transform(players):
    players['height'] = players['height'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    players['height'] = players['height'] * 2.54  # 转换为厘米
    players['weight'] = players['weight'] * 0.453592  # 转换为千克

def convert_to_metric_units(df):
    yards_to_meters = 0.9144  # 码米转换
    df['s'] = df['s'] * yards_to_meters
    df['a'] = df['a'] * yards_to_meters
    return df

metric_transform(players)
convert_to_metric_units(tracking)

players.head()
tracking.head()
# Out:
#        gameId  playId    nflId     displayName  frameId  \
# 0  2022090800      56  35472.0  Rodger Saffold        1
# 1  2022090800      56  35472.0  Rodger Saffold        2
# 2  2022090800      56  35472.0  Rodger Saffold        3
# 3  2022090800      56  35472.0  Rodger Saffold        4
# 4  2022090800      56  35472.0  Rodger Saffold        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27
# 1  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13
# 2  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01
# 3  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90
# 4  2022-09-08 20:24:05.599999          76.0  BUF          left  88.72  26.80
#
#           s         a   dis       o     dir         event
# 0  1.481328  1.051560  0.16  231.74  147.90           NaN
# 1  1.527048  0.557784  0.17  230.98  148.53  pass_arrived
# 2  1.435608  0.448056  0.15  230.98  147.05           NaN
# 3  1.316736  0.813816  0.14  232.38  145.42           NaN
# 4  1.179576  1.133856  0.13  233.36  141.95           NaN

# %%
"""
标准化方向数据，统一参考系，向左的都向右。
"""
def reverse_deg(deg):
    if deg < 180:
        return deg + 180
    if deg >= 180:
        return deg - 180
    
tracking["o_standard"]=np.where(tracking["playDirection"] == "left", tracking["o"].apply(reverse_deg), tracking["o"])
        
tracking["dir_standard"] = np.where(tracking["playDirection"] == "left", tracking["dir"].apply(reverse_deg), tracking["dir"])
        
tracking["x_standard"] = np.where(tracking["playDirection"] == "left", tracking["x"].apply(lambda x: 120 - x), tracking["x"])
        
tracking["y_standard"] =np.where(tracking["playDirection"] == "left",  tracking["y"].apply(lambda y: 160/3 - y), tracking["y"])

# %%
"""
plays新建一个'gameplayid'属性，gameId + playId
"""
def create_gameplayid(df):
    df['gameplayid']=df['gameId'].astype(str)+df['playId'].astype(str)
    return df

"""
tracking和tackles新建一个'index'属性，nflId + gameplayid
"""
def create_index(df):
    df['index']=df['nflId'].astype(str)+df['gameplayid']
    return df

tracking=create_index(create_gameplayid(tracking))
plays=create_gameplayid(plays)
tackles=create_index(create_gameplayid(tackles))

# %%
"""
统计表格信息
"""
def generate_summary_table(data):
    summary_table = pd.DataFrame(columns=['Column', 'Data Type', 'Missing Values', 'Missing %', 'Unique Values', 'Min', 'Max', 'Mean', 'Median'])
    
    for column in data.columns:
        data_type = str(data[column].dtype)
        
        missing_values = data[column].isnull().sum()
        missing_percentage = (missing_values / len(data)) * 100
        
        if data[column].dtype == 'object':
            min_value, max_value, mean_value, median_value = '', '', '', ''
        else:
            min_value = data[column].min()
            max_value = data[column].max()
            mean_value = data[column].mean()
            median_value = data[column].median()
        
        unique_values = data[column].nunique()
        
        summary_table = summary_table.append({
            'Column': column,
            'Data Type': data_type,
            'Missing Values': missing_values,
            'Missing %': f'{missing_percentage:.2f}%',
            'Unique Values': unique_values,
            'Min': min_value,
            'Max': max_value,
            'Mean': mean_value,
            'Median': median_value
        }, ignore_index=True)
    
    formatted_table = summary_table.style.set_properties(**{'text-align': 'center'})
    
    display(formatted_table)
    
    return summary_table

# %%
df_list = [games, plays, players, tackles, tracking]
df_names = ['games', 'plays', 'players', 'tackles', 'tracking']
for df, df_name in zip(df_list, df_names):
    print(f'{df_name}统计信息：')
    summary = generate_summary_table(df)
# Out:
# games统计信息：
# <style  type="text/css" >
# #T_d9903_row0_col0,#T_d9903_row0_col1,#T_d9903_row0_col2,#T_d9903_row0_col3,#T_d9903_row0_col4,#T_d9903_row0_col5,#T_d9903_row0_col6,#T_d9903_row0_col7,#T_d9903_row0_col8,#T_d9903_row1_col0,#T_d9903_row1_col1,#T_d9903_row1_col2,#T_d9903_row1_col3,#T_d9903_row1_col4,#T_d9903_row1_col5,#T_d9903_row1_col6,#T_d9903_row1_col7,#T_d9903_row1_col8,#T_d9903_row2_col0,#T_d9903_row2_col1,#T_d9903_row2_col2,#T_d9903_row2_col3,#T_d9903_row2_col4,#T_d9903_row2_col5,#T_d9903_row2_col6,#T_d9903_row2_col7,#T_d9903_row2_col8,#T_d9903_row3_col0,#T_d9903_row3_col1,#T_d9903_row3_col2,#T_d9903_row3_col3,#T_d9903_row3_col4,#T_d9903_row3_col5,#T_d9903_row3_col6,#T_d9903_row3_col7,#T_d9903_row3_col8,#T_d9903_row4_col0,#T_d9903_row4_col1,#T_d9903_row4_col2,#T_d9903_row4_col3,#T_d9903_row4_col4,#T_d9903_row4_col5,#T_d9903_row4_col6,#T_d9903_row4_col7,#T_d9903_row4_col8,#T_d9903_row5_col0,#T_d9903_row5_col1,#T_d9903_row5_col2,#T_d9903_row5_col3,#T_d9903_row5_col4,#T_d9903_row5_col5,#T_d9903_row5_col6,#T_d9903_row5_col7,#T_d9903_row5_col8,#T_d9903_row6_col0,#T_d9903_row6_col1,#T_d9903_row6_col2,#T_d9903_row6_col3,#T_d9903_row6_col4,#T_d9903_row6_col5,#T_d9903_row6_col6,#T_d9903_row6_col7,#T_d9903_row6_col8,#T_d9903_row7_col0,#T_d9903_row7_col1,#T_d9903_row7_col2,#T_d9903_row7_col3,#T_d9903_row7_col4,#T_d9903_row7_col5,#T_d9903_row7_col6,#T_d9903_row7_col7,#T_d9903_row7_col8,#T_d9903_row8_col0,#T_d9903_row8_col1,#T_d9903_row8_col2,#T_d9903_row8_col3,#T_d9903_row8_col4,#T_d9903_row8_col5,#T_d9903_row8_col6,#T_d9903_row8_col7,#T_d9903_row8_col8{
#             text-align:  center;
#         }</style><table id="T_d9903_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Data Type</th>        <th class="col_heading level0 col2" >Missing Values</th>        <th class="col_heading level0 col3" >Missing %</th>        <th class="col_heading level0 col4" >Unique Values</th>        <th class="col_heading level0 col5" >Min</th>        <th class="col_heading level0 col6" >Max</th>        <th class="col_heading level0 col7" >Mean</th>        <th class="col_heading level0 col8" >Median</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d9903_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d9903_row0_col0" class="data row0 col0" >gameId</td>
#                         <td id="T_d9903_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_d9903_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_d9903_row0_col3" class="data row0 col3" >0.00%</td>
#                         <td id="T_d9903_row0_col4" class="data row0 col4" >136</td>
#                         <td id="T_d9903_row0_col5" class="data row0 col5" >2022090800</td>
#                         <td id="T_d9903_row0_col6" class="data row0 col6" >2022110700</td>
#                         <td id="T_d9903_row0_col7" class="data row0 col7" >2022098922.117647</td>
#                         <td id="T_d9903_row0_col8" class="data row0 col8" >2022100902.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_d9903_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d9903_row1_col0" class="data row1 col0" >season</td>
#                         <td id="T_d9903_row1_col1" class="data row1 col1" >int64</td>
#                         <td id="T_d9903_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_d9903_row1_col3" class="data row1 col3" >0.00%</td>
#                         <td id="T_d9903_row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_d9903_row1_col5" class="data row1 col5" >2022</td>
#                         <td id="T_d9903_row1_col6" class="data row1 col6" >2022</td>
#                         <td id="T_d9903_row1_col7" class="data row1 col7" >2022.000000</td>
#                         <td id="T_d9903_row1_col8" class="data row1 col8" >2022.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d9903_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d9903_row2_col0" class="data row2 col0" >week</td>
#                         <td id="T_d9903_row2_col1" class="data row2 col1" >int64</td>
#                         <td id="T_d9903_row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_d9903_row2_col3" class="data row2 col3" >0.00%</td>
#                         <td id="T_d9903_row2_col4" class="data row2 col4" >9</td>
#                         <td id="T_d9903_row2_col5" class="data row2 col5" >1</td>
#                         <td id="T_d9903_row2_col6" class="data row2 col6" >9</td>
#                         <td id="T_d9903_row2_col7" class="data row2 col7" >4.845588</td>
#                         <td id="T_d9903_row2_col8" class="data row2 col8" >5.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d9903_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d9903_row3_col0" class="data row3 col0" >gameDate</td>
#                         <td id="T_d9903_row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_d9903_row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_d9903_row3_col3" class="data row3 col3" >0.00%</td>
#                         <td id="T_d9903_row3_col4" class="data row3 col4" >27</td>
#                         <td id="T_d9903_row3_col5" class="data row3 col5" ></td>
#                         <td id="T_d9903_row3_col6" class="data row3 col6" ></td>
#                         <td id="T_d9903_row3_col7" class="data row3 col7" ></td>
#                         <td id="T_d9903_row3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d9903_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d9903_row4_col0" class="data row4 col0" >gameTimeEastern</td>
#                         <td id="T_d9903_row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_d9903_row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_d9903_row4_col3" class="data row4 col3" >0.00%</td>
#                         <td id="T_d9903_row4_col4" class="data row4 col4" >8</td>
#                         <td id="T_d9903_row4_col5" class="data row4 col5" ></td>
#                         <td id="T_d9903_row4_col6" class="data row4 col6" ></td>
#                         <td id="T_d9903_row4_col7" class="data row4 col7" ></td>
#                         <td id="T_d9903_row4_col8" class="data row4 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d9903_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d9903_row5_col0" class="data row5 col0" >homeTeamAbbr</td>
#                         <td id="T_d9903_row5_col1" class="data row5 col1" >object</td>
#                         <td id="T_d9903_row5_col2" class="data row5 col2" >0</td>
#                         <td id="T_d9903_row5_col3" class="data row5 col3" >0.00%</td>
#                         <td id="T_d9903_row5_col4" class="data row5 col4" >32</td>
#                         <td id="T_d9903_row5_col5" class="data row5 col5" ></td>
#                         <td id="T_d9903_row5_col6" class="data row5 col6" ></td>
#                         <td id="T_d9903_row5_col7" class="data row5 col7" ></td>
#                         <td id="T_d9903_row5_col8" class="data row5 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d9903_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d9903_row6_col0" class="data row6 col0" >visitorTeamAbbr</td>
#                         <td id="T_d9903_row6_col1" class="data row6 col1" >object</td>
#                         <td id="T_d9903_row6_col2" class="data row6 col2" >0</td>
# plays统计信息：
# <style  type="text/css" >
# #T_ae6f2_row0_col0,#T_ae6f2_row0_col1,#T_ae6f2_row0_col2,#T_ae6f2_row0_col3,#T_ae6f2_row0_col4,#T_ae6f2_row0_col5,#T_ae6f2_row0_col6,#T_ae6f2_row0_col7,#T_ae6f2_row0_col8,#T_ae6f2_row1_col0,#T_ae6f2_row1_col1,#T_ae6f2_row1_col2,#T_ae6f2_row1_col3,#T_ae6f2_row1_col4,#T_ae6f2_row1_col5,#T_ae6f2_row1_col6,#T_ae6f2_row1_col7,#T_ae6f2_row1_col8,#T_ae6f2_row2_col0,#T_ae6f2_row2_col1,#T_ae6f2_row2_col2,#T_ae6f2_row2_col3,#T_ae6f2_row2_col4,#T_ae6f2_row2_col5,#T_ae6f2_row2_col6,#T_ae6f2_row2_col7,#T_ae6f2_row2_col8,#T_ae6f2_row3_col0,#T_ae6f2_row3_col1,#T_ae6f2_row3_col2,#T_ae6f2_row3_col3,#T_ae6f2_row3_col4,#T_ae6f2_row3_col5,#T_ae6f2_row3_col6,#T_ae6f2_row3_col7,#T_ae6f2_row3_col8,#T_ae6f2_row4_col0,#T_ae6f2_row4_col1,#T_ae6f2_row4_col2,#T_ae6f2_row4_col3,#T_ae6f2_row4_col4,#T_ae6f2_row4_col5,#T_ae6f2_row4_col6,#T_ae6f2_row4_col7,#T_ae6f2_row4_col8,#T_ae6f2_row5_col0,#T_ae6f2_row5_col1,#T_ae6f2_row5_col2,#T_ae6f2_row5_col3,#T_ae6f2_row5_col4,#T_ae6f2_row5_col5,#T_ae6f2_row5_col6,#T_ae6f2_row5_col7,#T_ae6f2_row5_col8,#T_ae6f2_row6_col0,#T_ae6f2_row6_col1,#T_ae6f2_row6_col2,#T_ae6f2_row6_col3,#T_ae6f2_row6_col4,#T_ae6f2_row6_col5,#T_ae6f2_row6_col6,#T_ae6f2_row6_col7,#T_ae6f2_row6_col8,#T_ae6f2_row7_col0,#T_ae6f2_row7_col1,#T_ae6f2_row7_col2,#T_ae6f2_row7_col3,#T_ae6f2_row7_col4,#T_ae6f2_row7_col5,#T_ae6f2_row7_col6,#T_ae6f2_row7_col7,#T_ae6f2_row7_col8,#T_ae6f2_row8_col0,#T_ae6f2_row8_col1,#T_ae6f2_row8_col2,#T_ae6f2_row8_col3,#T_ae6f2_row8_col4,#T_ae6f2_row8_col5,#T_ae6f2_row8_col6,#T_ae6f2_row8_col7,#T_ae6f2_row8_col8,#T_ae6f2_row9_col0,#T_ae6f2_row9_col1,#T_ae6f2_row9_col2,#T_ae6f2_row9_col3,#T_ae6f2_row9_col4,#T_ae6f2_row9_col5,#T_ae6f2_row9_col6,#T_ae6f2_row9_col7,#T_ae6f2_row9_col8,#T_ae6f2_row10_col0,#T_ae6f2_row10_col1,#T_ae6f2_row10_col2,#T_ae6f2_row10_col3,#T_ae6f2_row10_col4,#T_ae6f2_row10_col5,#T_ae6f2_row10_col6,#T_ae6f2_row10_col7,#T_ae6f2_row10_col8,#T_ae6f2_row11_col0,#T_ae6f2_row11_col1,#T_ae6f2_row11_col2,#T_ae6f2_row11_col3,#T_ae6f2_row11_col4,#T_ae6f2_row11_col5,#T_ae6f2_row11_col6,#T_ae6f2_row11_col7,#T_ae6f2_row11_col8,#T_ae6f2_row12_col0,#T_ae6f2_row12_col1,#T_ae6f2_row12_col2,#T_ae6f2_row12_col3,#T_ae6f2_row12_col4,#T_ae6f2_row12_col5,#T_ae6f2_row12_col6,#T_ae6f2_row12_col7,#T_ae6f2_row12_col8,#T_ae6f2_row13_col0,#T_ae6f2_row13_col1,#T_ae6f2_row13_col2,#T_ae6f2_row13_col3,#T_ae6f2_row13_col4,#T_ae6f2_row13_col5,#T_ae6f2_row13_col6,#T_ae6f2_row13_col7,#T_ae6f2_row13_col8,#T_ae6f2_row14_col0,#T_ae6f2_row14_col1,#T_ae6f2_row14_col2,#T_ae6f2_row14_col3,#T_ae6f2_row14_col4,#T_ae6f2_row14_col5,#T_ae6f2_row14_col6,#T_ae6f2_row14_col7,#T_ae6f2_row14_col8,#T_ae6f2_row15_col0,#T_ae6f2_row15_col1,#T_ae6f2_row15_col2,#T_ae6f2_row15_col3,#T_ae6f2_row15_col4,#T_ae6f2_row15_col5,#T_ae6f2_row15_col6,#T_ae6f2_row15_col7,#T_ae6f2_row15_col8,#T_ae6f2_row16_col0,#T_ae6f2_row16_col1,#T_ae6f2_row16_col2,#T_ae6f2_row16_col3,#T_ae6f2_row16_col4,#T_ae6f2_row16_col5,#T_ae6f2_row16_col6,#T_ae6f2_row16_col7,#T_ae6f2_row16_col8,#T_ae6f2_row17_col0,#T_ae6f2_row17_col1,#T_ae6f2_row17_col2,#T_ae6f2_row17_col3,#T_ae6f2_row17_col4,#T_ae6f2_row17_col5,#T_ae6f2_row17_col6,#T_ae6f2_row17_col7,#T_ae6f2_row17_col8,#T_ae6f2_row18_col0,#T_ae6f2_row18_col1,#T_ae6f2_row18_col2,#T_ae6f2_row18_col3,#T_ae6f2_row18_col4,#T_ae6f2_row18_col5,#T_ae6f2_row18_col6,#T_ae6f2_row18_col7,#T_ae6f2_row18_col8,#T_ae6f2_row19_col0,#T_ae6f2_row19_col1,#T_ae6f2_row19_col2,#T_ae6f2_row19_col3,#T_ae6f2_row19_col4,#T_ae6f2_row19_col5,#T_ae6f2_row19_col6,#T_ae6f2_row19_col7,#T_ae6f2_row19_col8,#T_ae6f2_row20_col0,#T_ae6f2_row20_col1,#T_ae6f2_row20_col2,#T_ae6f2_row20_col3,#T_ae6f2_row20_col4,#T_ae6f2_row20_col5,#T_ae6f2_row20_col6,#T_ae6f2_row20_col7,#T_ae6f2_row20_col8,#T_ae6f2_row21_col0,#T_ae6f2_row21_col1,#T_ae6f2_row21_col2,#T_ae6f2_row21_col3,#T_ae6f2_row21_col4,#T_ae6f2_row21_col5,#T_ae6f2_row21_col6,#T_ae6f2_row21_col7,#T_ae6f2_row21_col8,#T_ae6f2_row22_col0,#T_ae6f2_row22_col1,#T_ae6f2_row22_col2,#T_ae6f2_row22_col3,#T_ae6f2_row22_col4,#T_ae6f2_row22_col5,#T_ae6f2_r ...
#             text-align:  center;
#         }</style><table id="T_ae6f2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Data Type</th>        <th class="col_heading level0 col2" >Missing Values</th>        <th class="col_heading level0 col3" >Missing %</th>        <th class="col_heading level0 col4" >Unique Values</th>        <th class="col_heading level0 col5" >Min</th>        <th class="col_heading level0 col6" >Max</th>        <th class="col_heading level0 col7" >Mean</th>        <th class="col_heading level0 col8" >Median</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae6f2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ae6f2_row0_col0" class="data row0 col0" >gameId</td>
#                         <td id="T_ae6f2_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_ae6f2_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_ae6f2_row0_col3" class="data row0 col3" >0.00%</td>
#                         <td id="T_ae6f2_row0_col4" class="data row0 col4" >136</td>
#                         <td id="T_ae6f2_row0_col5" class="data row0 col5" >2022090800</td>
#                         <td id="T_ae6f2_row0_col6" class="data row0 col6" >2022110700</td>
#                         <td id="T_ae6f2_row0_col7" class="data row0 col7" >2022098953.855598</td>
#                         <td id="T_ae6f2_row0_col8" class="data row0 col8" >2022100903.000000</td
# players统计信息：
# <style  type="text/css" >
# #T_fdeff_row0_col0,#T_fdeff_row0_col1,#T_fdeff_row0_col2,#T_fdeff_row0_col3,#T_fdeff_row0_col4,#T_fdeff_row0_col5,#T_fdeff_row0_col6,#T_fdeff_row0_col7,#T_fdeff_row0_col8,#T_fdeff_row1_col0,#T_fdeff_row1_col1,#T_fdeff_row1_col2,#T_fdeff_row1_col3,#T_fdeff_row1_col4,#T_fdeff_row1_col5,#T_fdeff_row1_col6,#T_fdeff_row1_col7,#T_fdeff_row1_col8,#T_fdeff_row2_col0,#T_fdeff_row2_col1,#T_fdeff_row2_col2,#T_fdeff_row2_col3,#T_fdeff_row2_col4,#T_fdeff_row2_col5,#T_fdeff_row2_col6,#T_fdeff_row2_col7,#T_fdeff_row2_col8,#T_fdeff_row3_col0,#T_fdeff_row3_col1,#T_fdeff_row3_col2,#T_fdeff_row3_col3,#T_fdeff_row3_col4,#T_fdeff_row3_col5,#T_fdeff_row3_col6,#T_fdeff_row3_col7,#T_fdeff_row3_col8,#T_fdeff_row4_col0,#T_fdeff_row4_col1,#T_fdeff_row4_col2,#T_fdeff_row4_col3,#T_fdeff_row4_col4,#T_fdeff_row4_col5,#T_fdeff_row4_col6,#T_fdeff_row4_col7,#T_fdeff_row4_col8,#T_fdeff_row5_col0,#T_fdeff_row5_col1,#T_fdeff_row5_col2,#T_fdeff_row5_col3,#T_fdeff_row5_col4,#T_fdeff_row5_col5,#T_fdeff_row5_col6,#T_fdeff_row5_col7,#T_fdeff_row5_col8,#T_fdeff_row6_col0,#T_fdeff_row6_col1,#T_fdeff_row6_col2,#T_fdeff_row6_col3,#T_fdeff_row6_col4,#T_fdeff_row6_col5,#T_fdeff_row6_col6,#T_fdeff_row6_col7,#T_fdeff_row6_col8{
#             text-align:  center;
#         }</style><table id="T_fdeff_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Data Type</th>        <th class="col_heading level0 col2" >Missing Values</th>        <th class="col_heading level0 col3" >Missing %</th>        <th class="col_heading level0 col4" >Unique Values</th>        <th class="col_heading level0 col5" >Min</th>        <th class="col_heading level0 col6" >Max</th>        <th class="col_heading level0 col7" >Mean</th>        <th class="col_heading level0 col8" >Median</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fdeff_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fdeff_row0_col0" class="data row0 col0" >nflId</td>
#                         <td id="T_fdeff_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_fdeff_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_fdeff_row0_col3" class="data row0 col3" >0.00%</td>
#                         <td id="T_fdeff_row0_col4" class="data row0 col4" >1683</td>
#                         <td id="T_fdeff_row0_col5" class="data row0 col5" >25511</td>
#                         <td id="T_fdeff_row0_col6" class="data row0 col6" >55241</td>
#                         <td id="T_fdeff_row0_col7" class="data row0 col7" >48221.702317</td>
#                         <td id="T_fdeff_row0_col8" class="data row0 col8" >47872.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdeff_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fdeff_row1_col0" class="data row1 col0" >height</td>
#                         <td id="T_fdeff_row1_col1" class="data row1 col1" >float64</td>
#                         <td id="T_fdeff_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_fdeff_row1_col3" class="data row1 col3" >0.00%</td>
#                         <td id="T_fdeff_row1_col4" class="data row1 col4" >16</td>
#                         <td id="T_fdeff_row1_col5" class="data row1 col5" >167.640000</td>
#                         <td id="T_fdeff_row1_col6" class="data row1 col6" >205.740000</td>
#                         <td id="T_fdeff_row1_col7" class="data row1 col7" >188.604433</td>
#                         <td id="T_fdeff_row1_col8" class="data row1 col8" >190.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdeff_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fdeff_row2_col0" class="data row2 col0" >weight</td>
#                         <td id="T_fdeff_row2_col1" class="data row2 col1" >float64</td>
#                         <td id="T_fdeff_row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_fdeff_row2_col3" class="data row2 col3" >0.00%</td>
#                         <td id="T_fdeff_row2_col4" class="data row2 col4" >179</td>
#                         <td id="T_fdeff_row2_col5" class="data row2 col5" >69.399576</td>
#                         <td id="T_fdeff_row2_col6" class="data row2 col6" >172.364960</td>
#                         <td id="T_fdeff_row2_col7" class="data row2 col7" >111.458578</td>
#                         <td id="T_fdeff_row2_col8" class="data row2 col8" >107.047712</td>
#             </tr>
#             <tr>
#                         <th id="T_fdeff_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fdeff_row3_col0" class="data row3 col0" >birthDate</td>
#                         <td id="T_fdeff_row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_fdeff_row3_col2" class="data row3 col2" >479</td>
#                         <td id="T_fdeff_row3_col3" class="data row3 col3" >28.46%</td>
#                         <td id="T_fdeff_row3_col4" class="data row3 col4" >985</td>
#                         <td id="T_fdeff_row3_col5" class="data row3 col5" ></td>
#                         <td id="T_fdeff_row3_col6" class="data row3 col6" ></td>
#                         <td id="T_fdeff_row3_col7" class="data row3 col7" ></td>
#                         <td id="T_fdeff_row3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_fdeff_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fdeff_row4_col0" class="data row4 col0" >collegeName</td>
#                         <td id="T_fdeff_row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_fdeff_row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_fdeff_row4_col3" class="data row4 col3" >0.00%</td>
#                         <td id="T_fdeff_row4_col4" class="data row4 col4" >226</td>
#                         <td id="T_fdeff_row4_col5" class="data row4 col5" ></td>
#                         <td id="T_fdeff_row4_col6" class="data row4 col6" ></td>
#                         <td id="T_fdeff_row4_col7" class="data row4 col7" ></td>
#                         <td id="T_fdeff_row4_col8" class="data row4 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_fdeff_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fdeff_row5_col0" class="data row5 col0" >position</td>
#                         <td id="T_fdeff_row5_col1" class="data row5 col1" >object</td>
#                         <td id="T_fdeff_row5_col2" class="data row5 col2" >0</td>
#                         <td id="T_fdeff_row5_col3" class="data row5 col3" >0.00%</td>
#                         <td id="T_fdeff_row5_col4" class="data row5 col4" >19</td>
#                         <td id="T_fdeff_row5_col5" class="data row5 col5" ></td>
#                         <td id="T_fdeff_row5_col6" class="data row5 col6" ></td>
#                         <td id="T_fdeff_row5_col7" class="data row5 col7" ></td>
#                         <td id="T_fdeff_row5_col8" class="data row5 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_fdeff_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fdeff_row6_col0" class="data row6 col0" >displayName</td>
#                         <td id="T_fdeff_row6_col1" class="data row6 col1" >object</td>
#                         <td id="T_fdeff_row6_col2" class="data row6 col2" >0</td>
#                         <td id="T_fdeff_row6_col3" class="data row6 col3" >0.00%</td>
#                         <td id="T_fdeff_row6_col4" class="data row6 col4" >1672</td>
#                         <td id="T_fdeff_row6_col5" class="data row6 col5" ></td>
#                         <td id="T_fdeff_row6_col6" class="data row6 col6" ></td>
# tackles统计信息：
# <style  type="text/css" >
# #T_06a7a_row0_col0,#T_06a7a_row0_col1,#T_06a7a_row0_col2,#T_06a7a_row0_col3,#T_06a7a_row0_col4,#T_06a7a_row0_col5,#T_06a7a_row0_col6,#T_06a7a_row0_col7,#T_06a7a_row0_col8,#T_06a7a_row1_col0,#T_06a7a_row1_col1,#T_06a7a_row1_col2,#T_06a7a_row1_col3,#T_06a7a_row1_col4,#T_06a7a_row1_col5,#T_06a7a_row1_col6,#T_06a7a_row1_col7,#T_06a7a_row1_col8,#T_06a7a_row2_col0,#T_06a7a_row2_col1,#T_06a7a_row2_col2,#T_06a7a_row2_col3,#T_06a7a_row2_col4,#T_06a7a_row2_col5,#T_06a7a_row2_col6,#T_06a7a_row2_col7,#T_06a7a_row2_col8,#T_06a7a_row3_col0,#T_06a7a_row3_col1,#T_06a7a_row3_col2,#T_06a7a_row3_col3,#T_06a7a_row3_col4,#T_06a7a_row3_col5,#T_06a7a_row3_col6,#T_06a7a_row3_col7,#T_06a7a_row3_col8,#T_06a7a_row4_col0,#T_06a7a_row4_col1,#T_06a7a_row4_col2,#T_06a7a_row4_col3,#T_06a7a_row4_col4,#T_06a7a_row4_col5,#T_06a7a_row4_col6,#T_06a7a_row4_col7,#T_06a7a_row4_col8,#T_06a7a_row5_col0,#T_06a7a_row5_col1,#T_06a7a_row5_col2,#T_06a7a_row5_col3,#T_06a7a_row5_col4,#T_06a7a_row5_col5,#T_06a7a_row5_col6,#T_06a7a_row5_col7,#T_06a7a_row5_col8,#T_06a7a_row6_col0,#T_06a7a_row6_col1,#T_06a7a_row6_col2,#T_06a7a_row6_col3,#T_06a7a_row6_col4,#T_06a7a_row6_col5,#T_06a7a_row6_col6,#T_06a7a_row6_col7,#T_06a7a_row6_col8,#T_06a7a_row7_col0,#T_06a7a_row7_col1,#T_06a7a_row7_col2,#T_06a7a_row7_col3,#T_06a7a_row7_col4,#T_06a7a_row7_col5,#T_06a7a_row7_col6,#T_06a7a_row7_col7,#T_06a7a_row7_col8,#T_06a7a_row8_col0,#T_06a7a_row8_col1,#T_06a7a_row8_col2,#T_06a7a_row8_col3,#T_06a7a_row8_col4,#T_06a7a_row8_col5,#T_06a7a_row8_col6,#T_06a7a_row8_col7,#T_06a7a_row8_col8{
#             text-align:  center;
#         }</style><table id="T_06a7a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Data Type</th>        <th class="col_heading level0 col2" >Missing Values</th>        <th class="col_heading level0 col3" >Missing %</th>        <th class="col_heading level0 col4" >Unique Values</th>        <th class="col_heading level0 col5" >Min</th>        <th class="col_heading level0 col6" >Max</th>        <th class="col_heading level0 col7" >Mean</th>        <th class="col_heading level0 col8" >Median</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_06a7a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_06a7a_row0_col0" class="data row0 col0" >gameId</td>
#                         <td id="T_06a7a_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_06a7a_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_06a7a_row0_col3" class="data row0 col3" >0.00%</td>
#                         <td id="T_06a7a_row0_col4" class="data row0 col4" >136</td>
#                         <td id="T_06a7a_row0_col5" class="data row0 col5" >2022090800</td>
#                         <td id="T_06a7a_row0_col6" class="data row0 col6" >2022110700</td>
#                         <td id="T_06a7a_row0_col7" class="data row0 col7" >2022098971.441123</td>
#                         <td id="T_06a7a_row0_col8" class="data row0 col8" >2022100903.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_06a7a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_06a7a_row1_col0" class="data row1 col0" >playId</td>
#                         <td id="T_06a7a_row1_col1" class="data row1 col1" >int64</td>
#                         <td id="T_06a7a_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_06a7a_row1_col3" class="data row1 col3" >0.00%</td>
#                         <td id="T_06a7a_row1_col4" class="data row1 col4" >3943</td>
#                         <td id="T_06a7a_row1_col5" class="data row1 col5" >54</td>
#                         <td id="T_06a7a_row1_col6" class="data row1 col6" >5096</td>
#                         <td id="T_06a7a_row1_col7" class="data row1 col7" >1982.974578</td>
#                         <td id="T_06a7a_row1_col8" class="data row1 col8" >1991.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_06a7a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_06a7a_row2_col0" class="data row2 col0" >nflId</td>
#                         <td id="T_06a7a_row2_col1" class="data row2 col1" >int64</td>
#                         <td id="T_06a7a_row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_06a7a_row2_col3" class="data row2 col3" >0.00%</td>
#                         <td id="T_06a7a_row2_col4" class="data row2 col4" >800</td>
#                         <td id="T_06a7a_row2_col5" class="data row2 col5" >33131</td>
#                         <td id="T_06a7a_row2_col6" class="data row2 col6" >55241</td>
#                         <td id="T_06a7a_row2_col7" class="data row2 col7" >47602.719442</td>
#                         <td id="T_06a7a_row2_col8" class="data row2 col8" >46669.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_06a7a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_06a7a_row3_col0" class="data row3 col0" >tackle</td>
#                         <td id="T_06a7a_row3_col1" class="data row3 col1" >int64</td>
#                         <td id="T_06a7a_row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_06a7a_row3_col3" class="data row3 col3" >0.00%</td>
#                         <td id="T_06a7a_row3_col4" class="data row3 col4" >2</td>
#                         <td id="T_06a7a_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_06a7a_row3_col6" class="data row3 col6" >1</td>
#                         <td id="T_06a7a_row3_col7" class="data row3 col7" >0.569207</td>
#                         <td id="T_06a7a_row3_col8" class="data row3 col8" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_06a7a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_06a7a_row4_col0" class="data row4 col0" >assist</td>
#                         <td id="T_06a7a_row4_col1" class="data row4 col1" >int64</td>
#                         <td id="T_06a7a_row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_06a7a_row4_col3" class="data row4 col3" >0.00%</td>
#                         <td id="T_06a7a_row4_col4" class="data row4 col4" >2</td>
#                         <td id="T_06a7a_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_06a7a_row4_col6" class="data row4 col6" >1</td>
#                         <td id="T_06a7a_row4_col7" class="data row4 col7" >0.315276</td>
#                         <td id="T_06a7a_row4_col8" class="data row4 col8" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_06a7a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_06a7a_row5_col0" class="data row5 col0" >forcedFumble</td>
#                         <td id="T_06a7a_row5_col1" class="data row5 col1" >int64</td>
#                         <td id="T_06a7a_row5_col2" class="data row5 col2" >0</td>
#                         <td id="T_06a7a_row5_col3" class="data row5 col3" >0.00%</td>
#                         <td id="T_06a7a_row5_col4" class="data row5 col4" >2</td>
#                         <td id="T_06a7a_row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_06a7a_row5_col6" class="data row5 col6" >1</td>
#                         <td id="T_06a7a_row5_col7" class="data row5 col7" >0.005681</td>
#                         <td id="T_06a7a_row5_col8" class="data row5 col8" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_06a7a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_06a7a_row6_col0" class="data row6 col0" >pff_missedTackle</td>
#                         <td id="T_06a7a_row6_col1" class="data row6 col1" >int64</td>
#                         <td id="T_06a
# tracking统计信息：
# <style  type="text/css" >
# #T_7018b_row0_col0,#T_7018b_row0_col1,#T_7018b_row0_col2,#T_7018b_row0_col3,#T_7018b_row0_col4,#T_7018b_row0_col5,#T_7018b_row0_col6,#T_7018b_row0_col7,#T_7018b_row0_col8,#T_7018b_row1_col0,#T_7018b_row1_col1,#T_7018b_row1_col2,#T_7018b_row1_col3,#T_7018b_row1_col4,#T_7018b_row1_col5,#T_7018b_row1_col6,#T_7018b_row1_col7,#T_7018b_row1_col8,#T_7018b_row2_col0,#T_7018b_row2_col1,#T_7018b_row2_col2,#T_7018b_row2_col3,#T_7018b_row2_col4,#T_7018b_row2_col5,#T_7018b_row2_col6,#T_7018b_row2_col7,#T_7018b_row2_col8,#T_7018b_row3_col0,#T_7018b_row3_col1,#T_7018b_row3_col2,#T_7018b_row3_col3,#T_7018b_row3_col4,#T_7018b_row3_col5,#T_7018b_row3_col6,#T_7018b_row3_col7,#T_7018b_row3_col8,#T_7018b_row4_col0,#T_7018b_row4_col1,#T_7018b_row4_col2,#T_7018b_row4_col3,#T_7018b_row4_col4,#T_7018b_row4_col5,#T_7018b_row4_col6,#T_7018b_row4_col7,#T_7018b_row4_col8,#T_7018b_row5_col0,#T_7018b_row5_col1,#T_7018b_row5_col2,#T_7018b_row5_col3,#T_7018b_row5_col4,#T_7018b_row5_col5,#T_7018b_row5_col6,#T_7018b_row5_col7,#T_7018b_row5_col8,#T_7018b_row6_col0,#T_7018b_row6_col1,#T_7018b_row6_col2,#T_7018b_row6_col3,#T_7018b_row6_col4,#T_7018b_row6_col5,#T_7018b_row6_col6,#T_7018b_row6_col7,#T_7018b_row6_col8,#T_7018b_row7_col0,#T_7018b_row7_col1,#T_7018b_row7_col2,#T_7018b_row7_col3,#T_7018b_row7_col4,#T_7018b_row7_col5,#T_7018b_row7_col6,#T_7018b_row7_col7,#T_7018b_row7_col8,#T_7018b_row8_col0,#T_7018b_row8_col1,#T_7018b_row8_col2,#T_7018b_row8_col3,#T_7018b_row8_col4,#T_7018b_row8_col5,#T_7018b_row8_col6,#T_7018b_row8_col7,#T_7018b_row8_col8,#T_7018b_row9_col0,#T_7018b_row9_col1,#T_7018b_row9_col2,#T_7018b_row9_col3,#T_7018b_row9_col4,#T_7018b_row9_col5,#T_7018b_row9_col6,#T_7018b_row9_col7,#T_7018b_row9_col8,#T_7018b_row10_col0,#T_7018b_row10_col1,#T_7018b_row10_col2,#T_7018b_row10_col3,#T_7018b_row10_col4,#T_7018b_row10_col5,#T_7018b_row10_col6,#T_7018b_row10_col7,#T_7018b_row10_col8,#T_7018b_row11_col0,#T_7018b_row11_col1,#T_7018b_row11_col2,#T_7018b_row11_col3,#T_7018b_row11_col4,#T_7018b_row11_col5,#T_7018b_row11_col6,#T_7018b_row11_col7,#T_7018b_row11_col8,#T_7018b_row12_col0,#T_7018b_row12_col1,#T_7018b_row12_col2,#T_7018b_row12_col3,#T_7018b_row12_col4,#T_7018b_row12_col5,#T_7018b_row12_col6,#T_7018b_row12_col7,#T_7018b_row12_col8,#T_7018b_row13_col0,#T_7018b_row13_col1,#T_7018b_row13_col2,#T_7018b_row13_col3,#T_7018b_row13_col4,#T_7018b_row13_col5,#T_7018b_row13_col6,#T_7018b_row13_col7,#T_7018b_row13_col8,#T_7018b_row14_col0,#T_7018b_row14_col1,#T_7018b_row14_col2,#T_7018b_row14_col3,#T_7018b_row14_col4,#T_7018b_row14_col5,#T_7018b_row14_col6,#T_7018b_row14_col7,#T_7018b_row14_col8,#T_7018b_row15_col0,#T_7018b_row15_col1,#T_7018b_row15_col2,#T_7018b_row15_col3,#T_7018b_row15_col4,#T_7018b_row15_col5,#T_7018b_row15_col6,#T_7018b_row15_col7,#T_7018b_row15_col8,#T_7018b_row16_col0,#T_7018b_row16_col1,#T_7018b_row16_col2,#T_7018b_row16_col3,#T_7018b_row16_col4,#T_7018b_row16_col5,#T_7018b_row16_col6,#T_7018b_row16_col7,#T_7018b_row16_col8,#T_7018b_row17_col0,#T_7018b_row17_col1,#T_7018b_row17_col2,#T_7018b_row17_col3,#T_7018b_row17_col4,#T_7018b_row17_col5,#T_7018b_row17_col6,#T_7018b_row17_col7,#T_7018b_row17_col8,#T_7018b_row18_col0,#T_7018b_row18_col1,#T_7018b_row18_col2,#T_7018b_row18_col3,#T_7018b_row18_col4,#T_7018b_row18_col5,#T_7018b_row18_col6,#T_7018b_row18_col7,#T_7018b_row18_col8,#T_7018b_row19_col0,#T_7018b_row19_col1,#T_7018b_row19_col2,#T_7018b_row19_col3,#T_7018b_row19_col4,#T_7018b_row19_col5,#T_7018b_row19_col6,#T_7018b_row19_col7,#T_7018b_row19_col8,#T_7018b_row20_col0,#T_7018b_row20_col1,#T_7018b_row20_col2,#T_7018b_row20_col3,#T_7018b_row20_col4,#T_7018b_row20_col5,#T_7018b_row20_col6,#T_7018b_row20_col7,#T_7018b_row20_col8,#T_7018b_row21_col0,#T_7018b_row21_col1,#T_7018b_row21_col2,#T_7018b_row21_col3,#T_7018b_row21_col4,#T_7018b_row21_col5,#T_7018b_row21_col6,#T_7018b_row21_col7,#T_7018b_row21_col8,#T_7018b_row22_col0,#T_7018b_row22_col1,#T_7018b_row22_col2,#T_7018b_row22_col3,#T_7018b_row22_col4,#T_7018b_row22_col5,#T_7018b_r ...
#             text-align:  center;
#         }</style><table id="T_7018b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Data Type</th>        <th class="col_heading level0 col2" >Missing Values</th>        <th class="col_heading level0 col3" >Missing %</th>        <th class="col_heading level0 col4" >Unique Values</th>        <th class="col_heading level0 col5" >Min</th>        <th class="col_heading level0 col6" >Max</th>        <th class="col_heading level0 col7" >Mean</th>        <th class="col_heading level0 col8" >Median</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7018b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7018b_row0_col0" class="data row0 col0" >gameId</td>
#                         <td id="T_7018b_row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_7018b_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_7018b_row0_col3" class="data row0 col3" >0.00%</td>
#                         <td id="T_7018b_row0_col4" class="data row0 col4" >136</td>
#                         <td id="T_7018b_row0_col5" class="data row0 col5" >2022090800</td>
#                         <td id="T_7018b_row0_col6" class="data row0 col6" >2022110700</td>
#                         <td id="T_7018b_row0_col7" class="data row0 col7" >2022099002.717871</td>
#                         <td id="T_7018b_row0_col8" class="data row0 col8" >2022100904.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_7018b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7018b_row1_col0" class="data row1 col0" >playId</td>
#                         <td id="T_7018b_row1_col1" class="data row1 col1" >int64</td>
#                         <td id="T_7018b_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_7018b_row1_col3" class="data row1 col3" >0.00%</td>
#                         <td id="T_7018b_row1_col4" class="data row1 col4" >3974</td>
#                         <td id="T_7018b_row1_col5" class="data row1 col5" >54</td>
#                         <td id="T_7018b_row1_col6" class="data row1 col6" >5096</td>
#                         <td id="T_7018b_row1_col7" class="data row1 col7" >1981.028187</td>
#                         <td id="T_7018b_row1_col8" class="data row1 col8" >1997.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_7018b_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7018b_row2_col0" class="data row2 col0" >nflId</td>
#                         <td id="T_7018b_row2_col1" class="data row2 col1" >float64</td>
#                         <td id="T_7018b_row2_col2" class="data row2 col2" >530060</td>
#                         <td id="T_7018b_row2_col3" class="data row2 col3" >4.35%</td>
#                         <td id="T_7018b_row2_col4" class="data row2 col4" >1683</td>
#                         <td id="T_7018b_row2_col5" class="data row2 col5" >25511.000000</td>
#                         <td id="T_7018b_row2_col6" class="data row2 col6" >55241.000000</td>
#                         <td id="T_7018b_row2_col7" class="data row2 col7" >47459.700224</td>
#                         <td id="T_7018b_row2_col8" class="data row2 col8" >46521.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_7018b_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7018b_row3_col0" class="data row3 col0" >displayName</td>
#                         <td id="T_7018b_row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_7018b_row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_7018b_row3_col3" class="data row3 col3" >0.00%</td>
#                         <

# %%
"""
合并数据
"""
def merge_clean_data(tracking, df_plays, df_tackles):
    # 合并
    merged_df = pd.merge(
        pd.merge(tracking, df_plays, on=['gameplayid', 'gameId', 'playId'], how='inner'),
        df_tackles,
        on=['gameplayid', 'gameId', 'playId', 'nflId'],
        how='inner'
    )
    
    # 创建‘event’列
    for index, row in merged_df.iterrows():
        if row['tackle'] == 1:
            merged_df.at[index, 'event'] = 'tackle'
        elif row['pff_missedTackle'] == 1:
            merged_df.at[index, 'event'] = 'missed_tackle'
        elif row['assist'] == 1:
            merged_df.at[index, 'event'] = 'assist'
        else:
            merged_df.at[index, 'event'] = 'Other'

    
    # 再次合并
    df_tackles_final = pd.merge(
        merged_df,
        df_tackles,
        on=['gameplayid', 'gameId', 'playId', 'nflId', 'tackle', 'assist', 'pff_missedTackle'],
        how='inner',
        suffixes=['_1', '_2']
    )
    
    # 过滤行并创建'index'列
    index_values = []
    for index, row in df_tackles_final.iterrows():
        # 过滤全零
        if (row['tackle'] + row['assist'] + row['pff_missedTackle']) >= 1:
            # 过滤空id
            if not pd.isna(row['gameplayid']):
                # 计算index
                index_value = str(row['nflId']) + str(int(row['gameplayid']))
                index_values.append(index_value)

    # 将index加入df
    df_tackles_final['index'] = index_values
    
    return df_tackles_final


df_tackles_final=merge_clean_data(tracking, plays, tackles)
# Out:
# c:\Users\spdor\anaconda3\envs\python_all\lib\site-packages\pandas\core\reshape\merge.py:1140: RuntimeWarning: invalid value encountered in cast
#   if not (lk == lk.astype(rk.dtype))[~np.isnan(lk)].all():

# %%
df_tackles_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804159 entries, 0 to 804158
# Data columns (total 63 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   gameId                            804159 non-null  int64
#  1   playId                            804159 non-null  int64
#  2   nflId                             804159 non-null  float64
#  3   displayName                       804159 non-null  object
#  4   frameId                           804159 non-null  int64
#  5   time                              804159 non-null  object
#  6   jerseyNumber                      804159 non-null  float64
#  7   club                              804159 non-null  object
#  8   playDirection                     804159 non-null  object
#  9   x                                 804159 non-null  float64
#  10  y                                 804159 non-null  float64
#  11  s                                 804159 non-null  float64
#  12  a                                 804159 non-null  float64
#  13  dis                               804159 non-null  float64
#  14  o                                 804159 non-null  float64
#  15  dir                               804159 non-null  float64
#  16  event                             804159 non-null  object
#  17  o_standard                        804159 non-null  float64
#  18  dir_standard                      804159 non-null  float64
#  19  x_standard                        804159 non-null  float64
#  20  y_standard                        804159 non-null  float64
#  21  gameplayid                        804159 non-null  object
#  22  index_x                           804159 non-null  object
#  23  ballCarrierId                     804159 non-null  int64
#  24  ballCarrierDisplayName            804159 non-null  object
#  25  playDescription                   804159 non-null  object
#  26  quarter                           804159 non-null  int64
#  27  down                              804159 non-null  int64
#  28  yardsToGo                         804159 non-null  int64
#  29  possessionTeam                    804159 non-null  object
#  30  defensiveTeam                     804159 non-null  object
#  31  yardlineSide                      793277 non-null  object
#  32  yardlineNumber                    804159 non-null  int64
#  33  gameClock                         804159 non-null  object
#  34  preSnapHomeScore                  804159 non-null  int64
#  35  preSnapVisitorScore               804159 non-null  int64
#  36  passResult                        245481 non-null  object
#  37  passLength                        222762 non-null  float64
#  38  penaltyYards                      36318 non-null   float64
#  39  prePenaltyPlayResult              804159 non-null  int64
#  40  playResult                        804159 non-null  int64
#  41  playNullifiedByPenalty            804159 non-null  object
#  42  absoluteYardlineNumber            804159 non-null  int64
#  43  offenseFormation                  804064 non-null  object
#  44  defendersInTheBox                 803986 non-null  float64
#  45  passProbability                   784131 non-null  float64
#  46  preSnapHomeTeamWinProbability     804159 non-null  float64
#  47  preSnapVisitorTeamWinProbability  804159 non-null  float64
#  48  homeTeamWinProbabilityAdded       804159 non-null  float64
#  49  visitorTeamWinProbilityAdded      804159 non-null  float64
#  50  expectedPoints                    804159 non-null  float64
#  51  expectedPointsAdded               804069 non-null  float64
#  52  foulName1                         34841 non-null   object
#  53  foulName2                         1499 non-null    object
#  54  foulNFLId1                        34841 non-null   float64
#  55  foulNFLId2                        1499 non-null    float64
#  56  tackle                            804159 non-null  int64
#  57  assist                            804159 non-null  int64
#  58  forcedFumble_1                    804159 non-null  int64
#  59  pff_missedTackle                  804159 non-null  int64
#  60  index_y                           804159 non-null  object
#  61  forcedFumble_2                    804159 non-null  int64
#  62  index                             804159 non-null  object
# dtypes: float64(25), int64(18), object(20)
# memory usage: 392.7+ MB

# %%
"""
将player中是持球人信息提出来，作为新的df
"""
def create_ballcarrier_dataframe(df_players, tracking):
    # 提取ballCarriers信息
    df_ballcarrier_players = df_players.copy()
    df_ballcarrier_players.columns = [
        'nflId_ballcarrier', 'ballCarrierHeight', 'ballCarrierWeight',
        'ballcarrierBirth', 'ballcarrierCollege', 'ballcarrierPosition',
        'ballCarrierDisplayName'
    ]

    # 选择tracking中的相关列
    df_tracking_ballcarrier = tracking[[
        'gameplayid', 'frameId', 'nflId', 'x', 'y', 's', 'a', 'dis', 'o', 'dir',
        'event', 'o_standard', 'dir_standard', 'x_standard', 'y_standard'
    ]]

    # 合并players和tracking
    df_ballcarrier = pd.merge(df_tracking_ballcarrier, df_ballcarrier_players, left_on='nflId', right_on='nflId_ballcarrier')

    # 选择所需的列
    df_ballcarrier = df_ballcarrier[[
        'gameplayid', 'frameId', 'x', 'y', 's', 'a', 'dis', 'o', 'dir', 'event',
        'o_standard', 'dir_standard', 'x_standard', 'y_standard',
        'nflId_ballcarrier', 'ballCarrierHeight', 'ballCarrierWeight',
        'ballcarrierBirth', 'ballcarrierCollege', 'ballcarrierPosition',
        'ballCarrierDisplayName'
    ]]

    # 重命名列名
    df_ballcarrier.columns = [
        'gameplayid', 'frameId', 'x_ballcarrier', 'y_ballcarrier',
        's_ballcarrier', 'a_ballcarrier', 'dis_ballcarrier', 'o_ballcarrier',
        'dir_ballcarrier', 'event_ballcarrier', 'o_standard_ballcarrier',
        'dir_standard_ballcarrier', 'x_standard_ballcarrier',
        'y_standard_ballcarrier', 'nflId_ballcarrier', 'ballCarrierHeight',
        'ballCarrierWeight', 'ballcarrierBirth', 'ballcarrierCollege',
        'ballcarrierPosition', 'ballCarrierDisplayName'
    ]

    return df_ballcarrier

df_ballcarrier=create_ballcarrier_dataframe(players, tracking)
df_ballcarrier.head()
# Out:
#      gameplayid  frameId  x_ballcarrier  y_ballcarrier  s_ballcarrier  \
# 0  202209080056        1          88.37          27.27       1.481328
# 1  202209080056        2          88.47          27.13       1.527048
# 2  202209080056        3          88.56          27.01       1.435608
# 3  202209080056        4          88.64          26.90       1.316736
# 4  202209080056        5          88.72          26.80       1.179576
#
#    a_ballcarrier  dis_ballcarrier  o_ballcarrier  dir_ballcarrier  \
# 0       1.051560             0.16         231.74           147.90
# 1       0.557784             0.17         230.98           148.53
# 2       0.448056             0.15         230.98           147.05
# 3       0.813816             0.14         232.38           145.42
# 4       1.133856             0.13         233.36           141.95
#
#   event_ballcarrier  ...  dir_standard_ballcarrier  x_standard_ballcarrier  \
# 0               NaN  ...                    327.90                   31.63
# 1      pass_arrived  ...                    328.53                   31.53
# 2               NaN  ...                    327.05                   31.44
# 3               NaN  ...                    325.42                   31.36
# 4               NaN  ...                    321.95                   31.28
#
#    y_standard_ballcarrier  nflId_ballcarrier  ballCarrierHeight  \
# 0               26.063333              35472             195.58
# 1               26.203333              35472             195.58
# 2               26.323333              35472             195.58
# 3               26.433333              35472             195.58
# 4               26.533333              35472             195.58
#
#    ballCarrierWeight  ballcarrierBirth ballcarrierCollege ballcarrierPosition  \
# 0           147.4174        1988-06-06            Indiana                   G
# 1           147.4174        1988-06-06            Indiana                   G
# 2           147.4174        1988-06-06            Indiana                   G
# 3           147.4174        1988-06-06            Indiana                   G
# 4           147.4174        1988-06-06            Indiana                   G
#
#   ballCarrierDisplayName
# 0         Rodger Saffold
# 1         Rodger Saffold
# 2         Rodger Saffold
# 3         Rodger Saffold
# 4         Rodger Saffold
#
# [5 rows x 21 columns]

# %%
def merge_tackles_and_ballcarriers(df_tackles_final, players, df_ballcarrier):
    # 提取Tacklers信息
    df_players_tackler = players.copy()
    df_players_tackler.columns = [
        'nflId_tackler', 'tacklerHeight', 'tacklerWeight', 'tacklerBirth',
        'tacklerCollege', 'tacklerPosition', 'tacklerDisplayName'
    ]

    # 合并 df_tackles_final 与 df_players_tackler
    df_tackles_final = pd.merge(
        df_tackles_final, df_players_tackler,
        left_on='nflId', right_on='nflId_tackler'
    )

    # 合并 df_tackles_final 与 df_ballcarrier
    df_full = pd.merge(
        df_tackles_final, df_ballcarrier,
        left_on=['gameplayid', 'ballCarrierDisplayName', 'frameId'],
        right_on=['gameplayid', 'ballCarrierDisplayName', 'frameId']
    )

    # 重命名列名
    df_full.rename(columns={
        'nflId': 'nflId_tackler',
        'x': 'x_tackler',
        'y': 'y_tackler',
        's': 's_tackler',
        'a': 'a_tackler',
        'dis': 'dis_tackler',
        'o': 'o_tackler',
        'dir': 'dir_tackler',
        'event': 'event_tackler',
        'o_standard': 'o_standard_tackler',
        'dir_standard': 'dir_standard_tackler',
        'x_standard': 'x_standard_tackler',
        'y_standard': 'y_standard_tackler'
    }, inplace=True)

    return df_full

df_full=merge_tackles_and_ballcarriers(df_tackles_final, players, df_ballcarrier)
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804159 entries, 0 to 804158
# Data columns (total 88 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   gameId                            804159 non-null  int64
#  1   playId                            804159 non-null  int64
#  2   nflId_tackler                     804159 non-null  float64
#  3   displayName                       804159 non-null  object
#  4   frameId                           804159 non-null  int64
#  5   time                              804159 non-null  object
#  6   jerseyNumber                      804159 non-null  float64
#  7   club                              804159 non-null  object
#  8   playDirection                     804159 non-null  object
#  9   x_tackler                         804159 non-null  float64
#  10  y_tackler                         804159 non-null  float64
#  11  s_tackler                         804159 non-null  float64
#  12  a_tackler                         804159 non-null  float64
#  13  dis_tackler                       804159 non-null  float64
#  14  o_tackler                         804159 non-null  float64
#  15  dir_tackler                       804159 non-null  float64
#  16  event_tackler                     804159 non-null  object
#  17  o_standard_tackler                804159 non-null  float64
#  18  dir_standard_tackler              804159 non-null  float64
#  19  x_standard_tackler                804159 non-null  float64
#  20  y_standard_tackler                804159 non-null  float64
#  21  gameplayid                        804159 non-null  object
#  22  index_x                           804159 non-null  object
#  23  ballCarrierId                     804159 non-null  int64
#  24  ballCarrierDisplayName            804159 non-null  object
#  25  playDescription                   804159 non-null  object
#  26  quarter                           804159 non-null  int64
#  27  down                              804159 non-null  int64
#  28  yardsToGo                         804159 non-null  int64
#  29  possessionTeam                    804159 non-null  object
#  30  defensiveTeam                     804159 non-null  object
#  31  yardlineSide                      793277 non-null  object
#  32  yardlineNumber                    804159 non-null  int64
#  33  gameClock                         804159 non-null  object
#  34  preSnapHomeScore                  804159 non-null  int64
#  35  preSnapVisitorScore               804159 non-null  int64
#  36  passResult                        245481 non-null  object
#  37  passLength                        222762 non-null  float64
#  38  penaltyYards                      36318 non-null   float64
#  39  prePenaltyPlayResult              804159 non-null  int64
#  40  playResult                        804159 non-null  int64
#  41  playNullifiedByPenalty            804159 non-null  object
#  42  absoluteYardlineNumber            804159 non-null  int64
#  43  offenseFormation                  804064 non-null  object
#  44  defendersInTheBox                 803986 non-null  float64
#  45  passProbability                   784131 non-null  float64
#  46  preSnapHomeTeamWinProbability     804159 non-null  float64
#  47  preSnapVisitorTeamWinProbability  804159 non-null  float64
#  48  homeTeamWinProbabilityAdded       804159 non-null  float64
#  49  visitorTeamWinProbilityAdded      804159 non-null  float64
#  50  expectedPoints                    804159 non-null  float64
#  51  expectedPointsAdded               804069 non-null  float64
#  52  foulName1                         34841 non-null   object
#  53  foulName2                         1499 non-null    object
#  54  foulNFLId1                        34841 non-null   float64
#  55  foulNFLId2                        1499 non-null    float64
#  56  tackle                            804159 non-null  int64
#  57  assist                            804159 non-null  int64
#  58  forcedFumble_1                    804159 non-null  int64
#  59  pff_missedTackle                  804159 non-null  int64
#  60  index_y                           804159 non-null  object
#  61  forcedFumble_2                    804159 non-null  int64
#  62  index                             804159 non-null  object
#  63  nflId_tackler                     804159 non-null  int64
#  64  tacklerHeight                     804159 non-null  float64
#  65  tacklerWeight                     804159 non-null  float64
#  66  tacklerBirth                      628638 non-null  object
#  67  tacklerCollege                    804159 non-null  object
#  68  tacklerPosition                   804159 non-null  object
#  69  tacklerDisplayName                804159 non-null  object
#  70  x_ballcarrier                     804159 non-null  float64
#  71  y_ballcarrier                     804159 non-null  float64
#  72  s_ballcarrier                     804159 non-null  float64
#  73  a_ballcarrier                     804159 non-null  float64
#  74  dis_ballcarrier                   804159 non-null  float64
#  75  o_ballcarrier                     804159 non-null  float64
#  76  dir_ballcarrier                   804159 non-null  float64
#  77  event_ballcarrier                 67979 non-null   object
#  78  o_standard_ballcarrier            804159 non-null  float64
#  79  dir_standard_ballcarrier          804159 non-null  float64
#  80  x_standard_ballcarrier            804159 non-null  float64
#  81  y_standard_ballcarrier            804159 non-null  float64
#  82  nflId_ballcarrier                 804159 non-null  int64
#  83  ballCarrierHeight                 804159 non-null  float64
#  84  ballCarrierWeight                 804159 non-null  float64
#  85  ballcarrierBirth                  595905 non-null  object
#  86  ballcarrierCollege                804159 non-null  object
#  87  ballcarrierPosition               804159 non-null  object
# dtypes: float64(40), int64(20), object(28)
# memory usage: 546.0+ MB

# %%
"""
研究攻防球员的身体动态和静态属性、距离
"""
def create_motion_features(df_full):
    force_carrier = df_full['ballCarrierWeight'] * df_full['a_ballcarrier']
    force_tackler = df_full['tacklerWeight'] * df_full['a_tackler']

    # 动态(公制单位)
    df_full['force_ballcarrier'] = force_carrier
    df_full['force_tackler'] = force_tackler
    df_full['momentum_ballcarrier'] = df_full['ballCarrierWeight'] * df_full['s_ballcarrier']
    df_full['momentum_tackler'] = df_full['tacklerWeight'] * df_full['s_tackler']
    df_full['power_ballcarrier'] = force_carrier * df_full['s_ballcarrier']
    df_full['power_tackler'] = force_tackler * df_full['s_tackler']

    # 静态（公制单位）
    df_full['height_tackler_to_ballcarrier'] = df_full['tacklerHeight'] / df_full['ballCarrierHeight']
    df_full['dis_ballcarrier_tackler'] = np.sqrt(
        (df_full['x_standard_ballcarrier'] - df_full['x_standard_tackler']) ** 2 +
        (df_full['y_standard_ballcarrier'] - df_full['y_standard_tackler']) ** 2
    )

    return df_full

df_full=create_motion_features(df_full)
df_full.head()
# Out:
#        gameId  playId  nflId_tackler   displayName  frameId  \
# 0  2022090800      56        43294.0  Jalen Ramsey        1
# 1  2022090800      56        43294.0  Jalen Ramsey        2
# 2  2022090800      56        43294.0  Jalen Ramsey        3
# 3  2022090800      56        43294.0  Jalen Ramsey        4
# 4  2022090800      56        43294.0  Jalen Ramsey        5
#
#                          time  jerseyNumber club playDirection  x_tackler  \
# 0  2022-09-08 20:24:05.200000           5.0   LA          left      77.95
# 1  2022-09-08 20:24:05.299999           5.0   LA          left      78.02
# 2  2022-09-08 20:24:05.400000           5.0   LA          left      78.06
# 3  2022-09-08 20:24:05.500000           5.0   LA          left      78.10
# 4  2022-09-08 20:24:05.599999           5.0   LA          left      78.13
#
#    ...  ballcarrierCollege  ballcarrierPosition  force_ballcarrier  \
# 0  ...            Maryland                   WR          71.298022
# 1  ...            Maryland                   WR         100.609431
# 2  ...            Maryland                   WR         196.465660
# 3  ...            Maryland                   WR         266.971482
# 4  ...            Maryland                   WR         289.153088
#
#    force_tackler  momentum_ballcarrier  momentum_tackler power_ballcarrier  \
# 0     258.813063            493.540751        474.490616        406.164296
# 1     197.560638            494.332951        496.921082        574.062924
# 2     153.562418            473.735745        515.037996       1074.296234
# 3     101.799805            449.177537        519.351547       1384.153159
# 4      83.682891            430.164732        516.763417       1435.700602
#
#    power_tackler  height_tackler_to_ballcarrier  dis_ballcarrier_tackler
# 0    1301.622659                       1.013889                 3.636289
# 1    1040.540819                       1.013889                 3.528810
# 2     838.292324                       1.013889                 3.413210
# 3     560.376165                       1.013889                 3.258543
# 4     458.352614                       1.013889                 3.080260
#
# [5 rows x 96 columns]

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804159 entries, 0 to 804158
# Data columns (total 96 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   gameId                            804159 non-null  int64
#  1   playId                            804159 non-null  int64
#  2   nflId_tackler                     804159 non-null  float64
#  3   displayName                       804159 non-null  object
#  4   frameId                           804159 non-null  int64
#  5   time                              804159 non-null  object
#  6   jerseyNumber                      804159 non-null  float64
#  7   club                              804159 non-null  object
#  8   playDirection                     804159 non-null  object
#  9   x_tackler                         804159 non-null  float64
#  10  y_tackler                         804159 non-null  float64
#  11  s_tackler                         804159 non-null  float64
#  12  a_tackler                         804159 non-null  float64
#  13  dis_tackler                       804159 non-null  float64
#  14  o_tackler                         804159 non-null  float64
#  15  dir_tackler                       804159 non-null  float64
#  16  event_tackler                     804159 non-null  object
#  17  o_standard_tackler                804159 non-null  float64
#  18  dir_standard_tackler              804159 non-null  float64
#  19  x_standard_tackler                804159 non-null  float64
#  20  y_standard_tackler                804159 non-null  float64
#  21  gameplayid                        804159 non-null  object
#  22  index_x                           804159 non-null  object
#  23  ballCarrierId                     804159 non-null  int64
#  24  ballCarrierDisplayName            804159 non-null  object
#  25  playDescription                   804159 non-null  object
#  26  quarter                           804159 non-null  int64
#  27  down                              804159 non-null  int64
#  28  yardsToGo                         804159 non-null  int64
#  29  possessionTeam                    804159 non-null  object
#  30  defensiveTeam                     804159 non-null  object
#  31  yardlineSide                      793277 non-null  object
#  32  yardlineNumber                    804159 non-null  int64
#  33  gameClock                         804159 non-null  object
#  34  preSnapHomeScore                  804159 non-null  int64
#  35  preSnapVisitorScore               804159 non-null  int64
#  36  passResult                        245481 non-null  object
#  37  passLength                        222762 non-null  float64
#  38  penaltyYards                      36318 non-null   float64
#  39  prePenaltyPlayResult              804159 non-null  int64
#  40  playResult                        804159 non-null  int64
#  41  playNullifiedByPenalty            804159 non-null  object
#  42  absoluteYardlineNumber            804159 non-null  int64
#  43  offenseFormation                  804064 non-null  object
#  44  defendersInTheBox                 803986 non-null  float64
#  45  passProbability                   784131 non-null  float64
#  46  preSnapHomeTeamWinProbability     804159 non-null  float64
#  47  preSnapVisitorTeamWinProbability  804159 non-null  float64
#  48  homeTeamWinProbabilityAdded       804159 non-null  float64
#  49  visitorTeamWinProbilityAdded      804159 non-null  float64
#  50  expectedPoints                    804159 non-null  float64
#  51  expectedPointsAdded               804069 non-null  float64
#  52  foulName1                         34841 non-null   object
#  53  foulName2                         1499 non-null    object
#  54  foulNFLId1                        34841 non-null   float64
#  55  foulNFLId2                        1499 non-null    float64
#  56  tackle                            804159 non-null  int64
#  57  assist                            804159 non-null  int64
#  58  forcedFumble_1                    804159 non-null  int64
#  59  pff_missedTackle                  804159 non-null  int64
#  60  index_y                           804159 non-null  object
#  61  forcedFumble_2                    804159 non-null  int64
#  62  index                             804159 non-null  object
#  63  nflId_tackler                     804159 non-null  int64
#  64  tacklerHeight                     804159 non-null  float64
#  65  tacklerWeight                     804159 non-null  float64
#  66  tacklerBirth                      628638 non-null  object
#  67  tacklerCollege                    804159 non-null  object
#  68  tacklerPosition                   804159 non-null  object
#  69  tacklerDisplayName                804159 non-null  object
#  70  x_ballcarrier                     804159 non-null  float64
#  71  y_ballcarrier                     804159 non-null  float64
#  72  s_ballcarrier                     804159 non-null  float64
#  73  a_ballcarrier                     804159 non-null  float64
#  74  dis_ballcarrier                   804159 non-null  float64
#  75  o_ballcarrier                     804159 non-null  float64
#  76  dir_ballcarrier                   804159 non-null  float64
#  77  event_ballcarrier                 67979 non-null   object
#  78  o_standard_ballcarrier            804159 non-null  float64
#  79  dir_standard_ballcarrier          804159 non-null  float64
#  80  x_standard_ballcarrier            804159 non-null  float64
#  81  y_standard_ballcarrier            804159 non-null  float64
#  82  nflId_ballcarrier                 804159 non-null  int64
#  83  ballCarrierHeight                 804159 non-null  float64
#  84  ballCarrierWeight                 804159 non-null  float64
#  85  ballcarrierBirth                  595905 non-null  object
#  86  ballcarrierCollege                804159 non-null  object
#  87  ballcarrierPosition               804159 non-null  object
#  88  force_ballcarrier                 804159 non-null  float64
#  89  force_tackler                     804159 non-null  float64
#  90  momentum_ballcarrier              804159 non-null  float64
#  91  momentum_tackler                  804159 non-null  float64
#  92  power_ballcarrier                 804159 non-null  float64
#  93  power_tackler                     804159 non-null  float64
#  94  height_tackler_to_ballcarrier     804159 non-null  float64
#  95  dis_ballcarrier_tackler           804159 non-null  float64
# dtypes: float64(48), int64(20), object(28)
# memory usage: 595.1+ MB

# %%
def group_by_play(df_full):
    aggregation = {
        'time': ['min', 'max'],
        'offenseFormation': 'first',
        'tacklerPosition': pd.Series.mode,
        'ballcarrierPosition': pd.Series.mode,
        'x_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'y_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        's_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'a_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'dis_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'o_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'dir_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'o_standard_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'dir_standard_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'x_standard_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'y_standard_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'quarter': ['min', 'max', 'mean', 'std', 'skew'],
        'down': ['min', 'max', 'mean', 'std', 'skew'],
        'yardsToGo': ['min', 'max', 'mean', 'std', 'skew'],
        'gameClock': ['min', 'max'],
        'preSnapHomeScore': ['min', 'max', 'mean', 'std', 'skew'],
        'preSnapVisitorScore': ['min', 'max', 'mean', 'std', 'skew'],
        'passLength': ['min', 'max', 'mean', 'std', 'skew'],
        'absoluteYardlineNumber': ['min', 'max', 'mean', 'std', 'skew'],
        'defendersInTheBox': ['min', 'max', 'mean', 'std', 'skew'],
        'expectedPoints': ['min', 'max', 'mean', 'std', 'skew'],
        'tackle': 'max',
        'assist': 'max',
        'pff_missedTackle': 'max',
        'tacklerWeight': 'mean',
        'x_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'y_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        's_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'a_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'dis_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'o_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'o_standard_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'dir_standard_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'x_standard_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'y_standard_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'ballCarrierWeight': 'mean',
        'force_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'force_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'momentum_ballcarrier' : ['min', 'max', 'mean', 'std', 'skew'],
        'momentum_tackler' : ['min', 'max', 'mean', 'std', 'skew'],
        'power_ballcarrier': ['min', 'max', 'mean', 'std', 'skew'],
        'power_tackler': ['min', 'max', 'mean', 'std', 'skew'],
        'height_tackler_to_ballcarrier' : 'mean',
        'dis_ballcarrier_tackler': ['min', 'max', 'mean', 'std', 'skew']
    }
    
    df_full_grouped = df_full.groupby(['gameplayid', 'displayName']).agg(aggregation).reset_index()
    df_full_grouped.columns = ['|'.join(col).strip('|') for col in df_full_grouped.columns.values]
    
    return df_full_grouped

df_full_grouped=group_by_play(df_full)
df_full_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17420 entries, 0 to 17419
# Columns: 200 entries, gameplayid to dis_ballcarrier_tackler|skew
# dtypes: float64(163), int64(28), object(9)
# memory usage: 26.6+ MB

# %%
df_full_grouped.head()
# Out:
#        gameplayid    displayName                    time|min  \
# 0   2022090800101      Troy Hill  2022-09-08 20:25:08.200000
# 1  20220908001030     David Long  2022-09-08 21:01:44.799999
# 2  20220908001102  Terrell Lewis  2022-09-08 21:03:51.299999
# 3  20220908001102      Troy Hill  2022-09-08 21:03:51.299999
# 4  20220908001187   DaQuan Jones  2022-09-08 21:08:54.200000
#
#                      time|max offenseFormation|first tacklerPosition|mode  \
# 0  2022-09-08 20:25:13.000000                 I_FORM                   CB
# 1  2022-09-08 21:01:46.700000                SHOTGUN                   CB
# 2  2022-09-08 21:03:56.200000                SHOTGUN                  OLB
# 3  2022-09-08 21:03:56.200000                SHOTGUN                   CB
# 4  2022-09-08 21:08:59.599999             SINGLEBACK                   DT
#
#   ballcarrierPosition|mode  x_tackler|min  x_tackler|max  x_tackler|mean  ...  \
# 0                       RB          64.58          69.59       66.814898  ...
# 1                       WR          58.42          62.51       60.197000  ...
# 2                       RB          84.39          88.01       85.324000  ...
# 3                       RB          84.89          91.48       86.938200  ...
# 4                       RB          66.02          69.97       68.721091  ...
#
#    power_tackler|max  power_tackler|mean  power_tackler|std  \
# 0        1725.548112          620.835754         570.326424
# 1        1410.463799          912.115757         323.313177
# 2        1963.953349          642.233991         734.559958
# 3        1479.210714          391.896282         481.875368
# 4        1309.379222          450.068196         362.838584
#
#    power_tackler|skew  height_tackler_to_ballcarrier|mean  \
# 0            0.406975                            1.059701
# 1           -0.307915                            0.946667
# 2            0.766512                            1.100000
# 3            1.129921                            1.014286
# 4            0.860153                            1.117647
#
#    dis_ballcarrier_tackler|min  dis_ballcarrier_tackler|max  \
# 0                     0.353412                    18.915079
# 1                     0.319531                     3.061111
# 2                     0.325576                     6.310127
# 3                     0.375366                    10.380694
# 4                     0.630000                     7.788922
#
#    dis_ballcarrier_tackler|mean  dis_ballcarrier_tackler|std  \
# 0                     11.599050                     7.123702
# 1                      1.103907                     0.813950
# 2                      2.745755                     1.235816
# 3                      2.575385                     3.053362
# 4                      3.802571                     2.961672
#
#    dis_ballcarrier_tackler|skew
# 0                     -0.357283
# 1                      1.389278
# 2                      0.755065
# 3                      1.452462
# 4                      0.212843
#
# [5 rows x 200 columns]

# %%
generate_summary_table(df_full_grouped)
df_full_grouped.to_csv('../../processed_dataset/df_full_grouped.csv')
# Out:
# <style  type="text/css" >
# #T_85931_row0_col0,#T_85931_row0_col1,#T_85931_row0_col2,#T_85931_row0_col3,#T_85931_row0_col4,#T_85931_row0_col5,#T_85931_row0_col6,#T_85931_row0_col7,#T_85931_row0_col8,#T_85931_row1_col0,#T_85931_row1_col1,#T_85931_row1_col2,#T_85931_row1_col3,#T_85931_row1_col4,#T_85931_row1_col5,#T_85931_row1_col6,#T_85931_row1_col7,#T_85931_row1_col8,#T_85931_row2_col0,#T_85931_row2_col1,#T_85931_row2_col2,#T_85931_row2_col3,#T_85931_row2_col4,#T_85931_row2_col5,#T_85931_row2_col6,#T_85931_row2_col7,#T_85931_row2_col8,#T_85931_row3_col0,#T_85931_row3_col1,#T_85931_row3_col2,#T_85931_row3_col3,#T_85931_row3_col4,#T_85931_row3_col5,#T_85931_row3_col6,#T_85931_row3_col7,#T_85931_row3_col8,#T_85931_row4_col0,#T_85931_row4_col1,#T_85931_row4_col2,#T_85931_row4_col3,#T_85931_row4_col4,#T_85931_row4_col5,#T_85931_row4_col6,#T_85931_row4_col7,#T_85931_row4_col8,#T_85931_row5_col0,#T_85931_row5_col1,#T_85931_row5_col2,#T_85931_row5_col3,#T_85931_row5_col4,#T_85931_row5_col5,#T_85931_row5_col6,#T_85931_row5_col7,#T_85931_row5_col8,#T_85931_row6_col0,#T_85931_row6_col1,#T_85931_row6_col2,#T_85931_row6_col3,#T_85931_row6_col4,#T_85931_row6_col5,#T_85931_row6_col6,#T_85931_row6_col7,#T_85931_row6_col8,#T_85931_row7_col0,#T_85931_row7_col1,#T_85931_row7_col2,#T_85931_row7_col3,#T_85931_row7_col4,#T_85931_row7_col5,#T_85931_row7_col6,#T_85931_row7_col7,#T_85931_row7_col8,#T_85931_row8_col0,#T_85931_row8_col1,#T_85931_row8_col2,#T_85931_row8_col3,#T_85931_row8_col4,#T_85931_row8_col5,#T_85931_row8_col6,#T_85931_row8_col7,#T_85931_row8_col8,#T_85931_row9_col0,#T_85931_row9_col1,#T_85931_row9_col2,#T_85931_row9_col3,#T_85931_row9_col4,#T_85931_row9_col5,#T_85931_row9_col6,#T_85931_row9_col7,#T_85931_row9_col8,#T_85931_row10_col0,#T_85931_row10_col1,#T_85931_row10_col2,#T_85931_row10_col3,#T_85931_row10_col4,#T_85931_row10_col5,#T_85931_row10_col6,#T_85931_row10_col7,#T_85931_row10_col8,#T_85931_row11_col0,#T_85931_row11_col1,#T_85931_row11_col2,#T_85931_row11_col3,#T_85931_row11_col4,#T_85931_row11_col5,#T_85931_row11_col6,#T_85931_row11_col7,#T_85931_row11_col8,#T_85931_row12_col0,#T_85931_row12_col1,#T_85931_row12_col2,#T_85931_row12_col3,#T_85931_row12_col4,#T_85931_row12_col5,#T_85931_row12_col6,#T_85931_row12_col7,#T_85931_row12_col8,#T_85931_row13_col0,#T_85931_row13_col1,#T_85931_row13_col2,#T_85931_row13_col3,#T_85931_row13_col4,#T_85931_row13_col5,#T_85931_row13_col6,#T_85931_row13_col7,#T_85931_row13_col8,#T_85931_row14_col0,#T_85931_row14_col1,#T_85931_row14_col2,#T_85931_row14_col3,#T_85931_row14_col4,#T_85931_row14_col5,#T_85931_row14_col6,#T_85931_row14_col7,#T_85931_row14_col8,#T_85931_row15_col0,#T_85931_row15_col1,#T_85931_row15_col2,#T_85931_row15_col3,#T_85931_row15_col4,#T_85931_row15_col5,#T_85931_row15_col6,#T_85931_row15_col7,#T_85931_row15_col8,#T_85931_row16_col0,#T_85931_row16_col1,#T_85931_row16_col2,#T_85931_row16_col3,#T_85931_row16_col4,#T_85931_row16_col5,#T_85931_row16_col6,#T_85931_row16_col7,#T_85931_row16_col8,#T_85931_row17_col0,#T_85931_row17_col1,#T_85931_row17_col2,#T_85931_row17_col3,#T_85931_row17_col4,#T_85931_row17_col5,#T_85931_row17_col6,#T_85931_row17_col7,#T_85931_row17_col8,#T_85931_row18_col0,#T_85931_row18_col1,#T_85931_row18_col2,#T_85931_row18_col3,#T_85931_row18_col4,#T_85931_row18_col5,#T_85931_row18_col6,#T_85931_row18_col7,#T_85931_row18_col8,#T_85931_row19_col0,#T_85931_row19_col1,#T_85931_row19_col2,#T_85931_row19_col3,#T_85931_row19_col4,#T_85931_row19_col5,#T_85931_row19_col6,#T_85931_row19_col7,#T_85931_row19_col8,#T_85931_row20_col0,#T_85931_row20_col1,#T_85931_row20_col2,#T_85931_row20_col3,#T_85931_row20_col4,#T_85931_row20_col5,#T_85931_row20_col6,#T_85931_row20_col7,#T_85931_row20_col8,#T_85931_row21_col0,#T_85931_row21_col1,#T_85931_row21_col2,#T_85931_row21_col3,#T_85931_row21_col4,#T_85931_row21_col5,#T_85931_row21_col6,#T_85931_row21_col7,#T_85931_row21_col8,#T_85931_row22_col0,#T_85931_row22_col1,#T_85931_row22_col2,#T_85931_row22_col3,#T_85931_row22_col4,#T_85931_row22_col5,#T_85931_r ...

# %%
"""
摘要统计
"""
# 计算总的进攻次数
total_plays = df_full_grouped['gameplayid'].nunique()
total_rows = len(df_full_grouped)

# 计算总的未能完成的擒抱次数、助攻次数和擒抱次数
total_missed_tackles = len(df_full_grouped[df_full_grouped['pff_missedTackle|max'] == 1])
total_assists = len(df_full_grouped[(df_full_grouped['assist|max'] == 1) & (df_full_grouped['pff_missedTackle|max'] == 0)])
total_tackles = len(df_full_grouped[(df_full_grouped['tackle|max'] == 1) & 
                                   (df_full_grouped['assist|max'] == 0) & 
                                   (df_full_grouped['pff_missedTackle|max'] == 0)])

print('Total plays:', total_plays)
print('Total row count:', total_rows)
print('Total missed tackles:', total_missed_tackles)
print('Total assists:', total_assists)
print('Total tackles:', total_tackles)
# Out:
# Total plays: 12022
# Total row count: 17420
# Total missed tackles: 2090
# Total assists: 5446
# Total tackles: 9884

# %%
"""
特征选取
"""

# 增加位置变量
def create_position_variables(df_full_grouped):
    # 持球进攻球员位置
    ballcarrier_position = pd.get_dummies(
        df_full_grouped[['gameplayid', 'displayName', 'ballcarrierPosition|mode']],
        columns=['ballcarrierPosition|mode'], drop_first=True
    ).reset_index(drop=True)
    ballcarrier_position.columns = ['gameplayid', 'displayName', 'QB_ballcarrier', 'RB_ballcarrier', 'TE_ballcarrier', 'WR_ballcarrier']

    # 防守队员位置
    tackler_position = pd.get_dummies(
        df_full_grouped[['gameplayid', 'displayName', 'tacklerPosition|mode']],
        columns=['tacklerPosition|mode'], drop_first=True
    ).reset_index(drop=True)
    tackler_position.columns = ['gameplayid', 'displayName', 'tacklerPosition|mode_DB', 'tacklerPosition|mode_DE',
                                'tacklerPosition|mode_DT', 'tacklerPosition|mode_FS',
                                'tacklerPosition|mode_ILB', 'tacklerPosition|mode_MLB',
                                'tacklerPosition|mode_NT', 'tacklerPosition|mode_OLB',
                                'tacklerPosition|mode_SS']

    # 进攻阵型
    offense_formation = pd.get_dummies(
        df_full_grouped[['gameplayid', 'displayName', 'offenseFormation|first']],
        columns=['offenseFormation|first'], drop_first=True
    ).reset_index(drop=True)

    # 合并
    df_merge = df_full_grouped.merge(ballcarrier_position, on=['gameplayid', 'displayName'])
    df_merge = df_merge.merge(tackler_position, on=['gameplayid', 'displayName'])
    df_merge = df_merge.merge(offense_formation, on=['gameplayid', 'displayName'])

    return df_merge

df_full_grouped=create_position_variables(df_full_grouped)

# %%
# 合成最终的target
condition = (df_full_grouped['tackle|max'] + df_full_grouped['assist|max'] >= 1) & (df_full_grouped['pff_missedTackle|max'] == 0)
df_full_grouped['tackle_assist_success'] = np.where(condition, 1, 0)

df_full_grouped.info()
# df_full_grouped.to_csv('../../Dataset/full_grouped.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17420 entries, 0 to 17419
# Columns: 220 entries, gameplayid to tackle_assist_success
# dtypes: float64(163), int32(1), int64(28), object(9), uint8(19)
# memory usage: 27.1+ MB

# %%
df_final = df_full_grouped[df_full_grouped['tackle|max'] + df_full_grouped['pff_missedTackle|max'] >= 1]
print(f'合法进攻样本数：{len(df_final)}')
print(f'成功tackle/assist数：{df_final.tackle_assist_success.sum()}')
print(f"失败tackle数：{df_final['pff_missedTackle|max'].sum()}")
# Out:
# 合法进攻样本数：11974
# 成功tackle/assist数：9884
# 失败tackle数：2090

# %%
# final增加相对运动信息
def create_diff_range(df_final):
    df_final['difference_speed'] = df_final['s_tackler|max'] - df_final['s_ballcarrier|max']
    df_final['difference_a'] = df_final['a_tackler|max'] - df_final['a_ballcarrier|max']
    df_final['difference_orientation'] = df_final['o_standard_tackler|max'] - df_final['o_standard_ballcarrier|max']
    df_final['tackler_x_range'] = df_final['x_standard_tackler|max'] - df_final['x_standard_tackler|min']
    df_final['tackler_y_range'] = df_final['y_standard_tackler|max'] - df_final['y_standard_tackler|min']
    df_final['tackler_s_range'] = df_final['s_tackler|max'] - df_final['s_tackler|min']
    df_final['tackler_a_range'] = df_final['a_tackler|max'] - df_final['a_tackler|min']
    df_final['o_range_tackler'] = df_final['o_standard_tackler|max'] - df_final['o_standard_tackler|min']
    df_final['dir_range_tackler'] = df_final['dir_standard_tackler|max'] - df_final['dir_standard_tackler|min']
    df_final['ballcarrier_x_range'] = df_final['x_standard_ballcarrier|max'] - df_final['x_standard_ballcarrier|min']
    df_final['ballcarrier_y_range'] = df_final['y_standard_ballcarrier|max'] - df_final['y_standard_ballcarrier|min']
    df_final['ballcarrier_s_range'] = df_final['s_ballcarrier|max'] - df_final['s_ballcarrier|min']
    df_final['ballcarrier_a_range'] = df_final['a_ballcarrier|max'] - df_final['a_ballcarrier|min']
    df_final['o_range_ballcarrier'] = df_final['o_standard_ballcarrier|max'] - df_final['o_standard_ballcarrier|min']
    df_final['dir_range_ballcarrier'] = df_final['dir_standard_ballcarrier|max'] - df_final['dir_standard_ballcarrier|min']
    return df_final

Cleaned_Data = create_diff_range(df_final)
# Out:
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['difference_speed'] = df_final['s_tackler|max'] - df_final['s_ballcarrier|max']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['difference_a'] = df_final['a_tackler|max'] - df_final['a_ballcarrier|max']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['difference_orientation'] = df_final['o_standard_tackler|max'] - df_final['o_standard_ballcarrier|max']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tackler_x_range'] = df_final['x_standard_tackler|max'] - df_final['x_standard_tackler|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tackler_y_range'] = df_final['y_standard_tackler|max'] - df_final['y_standard_tackler|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tackler_s_range'] = df_final['s_tackler|max'] - df_final['s_tackler|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tackler_a_range'] = df_final['a_tackler|max'] - df_final['a_tackler|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['o_range_tackler'] = df_final['o_standard_tackler|max'] - df_final['o_standard_tackler|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['dir_range_tackler'] = df_final['dir_standard_tackler|max'] - df_final['dir_standard_tackler|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['ballcarrier_x_range'] = df_final['x_standard_ballcarrier|max'] - df_final['x_standard_ballcarrier|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['ballcarrier_y_range'] = df_final['y_standard_ballcarrier|max'] - df_final['y_standard_ballcarrier|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['ballcarrier_s_range'] = df_final['s_ballcarrier|max'] - df_final['s_ballcarrier|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['ballcarrier_a_range'] = df_final['a_ballcarrier|max'] - df_final['a_ballcarrier|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['o_range_ballcarrier'] = df_final['o_standard_ballcarrier|max'] - df_final['o_standard_ballcarrier|min']
# C:\Users\spdor\AppData\Local\Temp\ipykernel_24600\2657070312.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['dir_range_ballcarrier'] = df_final['dir_standard_ballcarrier|max'] - df_final['dir_standard_ballcarrier|min']

# %%
generate_summary_table(Cleaned_Data)
Cleaned_Data.to_csv('../../processed_dataset/Cleaned_Data.csv')
# Out:
# <style  type="text/css" >
# #T_0715f_row0_col0,#T_0715f_row0_col1,#T_0715f_row0_col2,#T_0715f_row0_col3,#T_0715f_row0_col4,#T_0715f_row0_col5,#T_0715f_row0_col6,#T_0715f_row0_col7,#T_0715f_row0_col8,#T_0715f_row1_col0,#T_0715f_row1_col1,#T_0715f_row1_col2,#T_0715f_row1_col3,#T_0715f_row1_col4,#T_0715f_row1_col5,#T_0715f_row1_col6,#T_0715f_row1_col7,#T_0715f_row1_col8,#T_0715f_row2_col0,#T_0715f_row2_col1,#T_0715f_row2_col2,#T_0715f_row2_col3,#T_0715f_row2_col4,#T_0715f_row2_col5,#T_0715f_row2_col6,#T_0715f_row2_col7,#T_0715f_row2_col8,#T_0715f_row3_col0,#T_0715f_row3_col1,#T_0715f_row3_col2,#T_0715f_row3_col3,#T_0715f_row3_col4,#T_0715f_row3_col5,#T_0715f_row3_col6,#T_0715f_row3_col7,#T_0715f_row3_col8,#T_0715f_row4_col0,#T_0715f_row4_col1,#T_0715f_row4_col2,#T_0715f_row4_col3,#T_0715f_row4_col4,#T_0715f_row4_col5,#T_0715f_row4_col6,#T_0715f_row4_col7,#T_0715f_row4_col8,#T_0715f_row5_col0,#T_0715f_row5_col1,#T_0715f_row5_col2,#T_0715f_row5_col3,#T_0715f_row5_col4,#T_0715f_row5_col5,#T_0715f_row5_col6,#T_0715f_row5_col7,#T_0715f_row5_col8,#T_0715f_row6_col0,#T_0715f_row6_col1,#T_0715f_row6_col2,#T_0715f_row6_col3,#T_0715f_row6_col4,#T_0715f_row6_col5,#T_0715f_row6_col6,#T_0715f_row6_col7,#T_0715f_row6_col8,#T_0715f_row7_col0,#T_0715f_row7_col1,#T_0715f_row7_col2,#T_0715f_row7_col3,#T_0715f_row7_col4,#T_0715f_row7_col5,#T_0715f_row7_col6,#T_0715f_row7_col7,#T_0715f_row7_col8,#T_0715f_row8_col0,#T_0715f_row8_col1,#T_0715f_row8_col2,#T_0715f_row8_col3,#T_0715f_row8_col4,#T_0715f_row8_col5,#T_0715f_row8_col6,#T_0715f_row8_col7,#T_0715f_row8_col8,#T_0715f_row9_col0,#T_0715f_row9_col1,#T_0715f_row9_col2,#T_0715f_row9_col3,#T_0715f_row9_col4,#T_0715f_row9_col5,#T_0715f_row9_col6,#T_0715f_row9_col7,#T_0715f_row9_col8,#T_0715f_row10_col0,#T_0715f_row10_col1,#T_0715f_row10_col2,#T_0715f_row10_col3,#T_0715f_row10_col4,#T_0715f_row10_col5,#T_0715f_row10_col6,#T_0715f_row10_col7,#T_0715f_row10_col8,#T_0715f_row11_col0,#T_0715f_row11_col1,#T_0715f_row11_col2,#T_0715f_row11_col3,#T_0715f_row11_col4,#T_0715f_row11_col5,#T_0715f_row11_col6,#T_0715f_row11_col7,#T_0715f_row11_col8,#T_0715f_row12_col0,#T_0715f_row12_col1,#T_0715f_row12_col2,#T_0715f_row12_col3,#T_0715f_row12_col4,#T_0715f_row12_col5,#T_0715f_row12_col6,#T_0715f_row12_col7,#T_0715f_row12_col8,#T_0715f_row13_col0,#T_0715f_row13_col1,#T_0715f_row13_col2,#T_0715f_row13_col3,#T_0715f_row13_col4,#T_0715f_row13_col5,#T_0715f_row13_col6,#T_0715f_row13_col7,#T_0715f_row13_col8,#T_0715f_row14_col0,#T_0715f_row14_col1,#T_0715f_row14_col2,#T_0715f_row14_col3,#T_0715f_row14_col4,#T_0715f_row14_col5,#T_0715f_row14_col6,#T_0715f_row14_col7,#T_0715f_row14_col8,#T_0715f_row15_col0,#T_0715f_row15_col1,#T_0715f_row15_col2,#T_0715f_row15_col3,#T_0715f_row15_col4,#T_0715f_row15_col5,#T_0715f_row15_col6,#T_0715f_row15_col7,#T_0715f_row15_col8,#T_0715f_row16_col0,#T_0715f_row16_col1,#T_0715f_row16_col2,#T_0715f_row16_col3,#T_0715f_row16_col4,#T_0715f_row16_col5,#T_0715f_row16_col6,#T_0715f_row16_col7,#T_0715f_row16_col8,#T_0715f_row17_col0,#T_0715f_row17_col1,#T_0715f_row17_col2,#T_0715f_row17_col3,#T_0715f_row17_col4,#T_0715f_row17_col5,#T_0715f_row17_col6,#T_0715f_row17_col7,#T_0715f_row17_col8,#T_0715f_row18_col0,#T_0715f_row18_col1,#T_0715f_row18_col2,#T_0715f_row18_col3,#T_0715f_row18_col4,#T_0715f_row18_col5,#T_0715f_row18_col6,#T_0715f_row18_col7,#T_0715f_row18_col8,#T_0715f_row19_col0,#T_0715f_row19_col1,#T_0715f_row19_col2,#T_0715f_row19_col3,#T_0715f_row19_col4,#T_0715f_row19_col5,#T_0715f_row19_col6,#T_0715f_row19_col7,#T_0715f_row19_col8,#T_0715f_row20_col0,#T_0715f_row20_col1,#T_0715f_row20_col2,#T_0715f_row20_col3,#T_0715f_row20_col4,#T_0715f_row20_col5,#T_0715f_row20_col6,#T_0715f_row20_col7,#T_0715f_row20_col8,#T_0715f_row21_col0,#T_0715f_row21_col1,#T_0715f_row21_col2,#T_0715f_row21_col3,#T_0715f_row21_col4,#T_0715f_row21_col5,#T_0715f_row21_col6,#T_0715f_row21_col7,#T_0715f_row21_col8,#T_0715f_row22_col0,#T_0715f_row22_col1,#T_0715f_row22_col2,#T_0715f_row22_col3,#T_0715f_row22_col4,#T_0715f_row22_col5,#T_0715f_r ...

# %%
# 选择Cleaned_Data中的数值列
Cleaned_Data_num = Cleaned_Data.select_dtypes(include=[np.number])

Cleaned_Data_num.head()
# Out:
#    x_tackler|min  x_tackler|max  x_tackler|mean  x_tackler|std  \
# 0          64.58          69.59       66.814898       2.092568
# 1          58.42          62.51       60.197000       1.491750
# 2          84.39          88.01       85.324000       1.015520
# 3          84.89          91.48       86.938200       1.752662
# 5          65.53          70.91       68.878182       1.720190
#
#    x_tackler|skew  y_tackler|min  y_tackler|max  y_tackler|mean  \
# 0        0.150261          39.18          44.13       41.712245
# 1        0.303782          36.76          38.61       37.428000
# 2        1.176394          41.76          44.98       42.907800
# 3        1.060643          38.92          44.44       42.940600
# 5       -0.613643          24.99          40.86       31.508909
#
#    y_tackler|std  y_tackler|skew  ...  tackler_s_range  tackler_a_range  \
# 0       1.458103        0.097733  ...         4.105656         5.806440
# 1       0.561873        0.565220  ...         2.048256         3.447288
# 2       1.061124        0.776466  ...         4.315968         6.080760
# 3       1.670280       -1.403647  ...         4.233672         4.251960
# 5       5.155330        0.122112  ...         4.544568         5.952744
#
#    o_range_tackler  dir_range_tackler  ballcarrier_x_range  \
# 0           335.82             352.70                14.42
# 1           342.47             163.92                 1.21
# 2           268.54             313.25                 5.18
# 3           164.37             138.38                 5.18
# 5           100.70             163.28                11.40
#
#    ballcarrier_y_range  ballcarrier_s_range  ballcarrier_a_range  \
# 0                11.11             6.638544             4.910328
# 1                 1.05             2.852928             4.023360
# 2                 3.65             4.251960             4.178808
# 3                 3.65             4.251960             4.178808
# 5                 9.60             4.645152             4.562856
#
#    o_range_ballcarrier  dir_range_ballcarrier
# 0               105.02                 107.21
# 1               330.49                 191.01
# 2               341.84                 324.63
# 3               341.84                 324.63
# 5               139.27                 113.53
#
# [5 rows x 226 columns]

# %%
generate_summary_table(Cleaned_Data_num)
# Out:
# <style  type="text/css" >
# #T_2bc27_row0_col0,#T_2bc27_row0_col1,#T_2bc27_row0_col2,#T_2bc27_row0_col3,#T_2bc27_row0_col4,#T_2bc27_row0_col5,#T_2bc27_row0_col6,#T_2bc27_row0_col7,#T_2bc27_row0_col8,#T_2bc27_row1_col0,#T_2bc27_row1_col1,#T_2bc27_row1_col2,#T_2bc27_row1_col3,#T_2bc27_row1_col4,#T_2bc27_row1_col5,#T_2bc27_row1_col6,#T_2bc27_row1_col7,#T_2bc27_row1_col8,#T_2bc27_row2_col0,#T_2bc27_row2_col1,#T_2bc27_row2_col2,#T_2bc27_row2_col3,#T_2bc27_row2_col4,#T_2bc27_row2_col5,#T_2bc27_row2_col6,#T_2bc27_row2_col7,#T_2bc27_row2_col8,#T_2bc27_row3_col0,#T_2bc27_row3_col1,#T_2bc27_row3_col2,#T_2bc27_row3_col3,#T_2bc27_row3_col4,#T_2bc27_row3_col5,#T_2bc27_row3_col6,#T_2bc27_row3_col7,#T_2bc27_row3_col8,#T_2bc27_row4_col0,#T_2bc27_row4_col1,#T_2bc27_row4_col2,#T_2bc27_row4_col3,#T_2bc27_row4_col4,#T_2bc27_row4_col5,#T_2bc27_row4_col6,#T_2bc27_row4_col7,#T_2bc27_row4_col8,#T_2bc27_row5_col0,#T_2bc27_row5_col1,#T_2bc27_row5_col2,#T_2bc27_row5_col3,#T_2bc27_row5_col4,#T_2bc27_row5_col5,#T_2bc27_row5_col6,#T_2bc27_row5_col7,#T_2bc27_row5_col8,#T_2bc27_row6_col0,#T_2bc27_row6_col1,#T_2bc27_row6_col2,#T_2bc27_row6_col3,#T_2bc27_row6_col4,#T_2bc27_row6_col5,#T_2bc27_row6_col6,#T_2bc27_row6_col7,#T_2bc27_row6_col8,#T_2bc27_row7_col0,#T_2bc27_row7_col1,#T_2bc27_row7_col2,#T_2bc27_row7_col3,#T_2bc27_row7_col4,#T_2bc27_row7_col5,#T_2bc27_row7_col6,#T_2bc27_row7_col7,#T_2bc27_row7_col8,#T_2bc27_row8_col0,#T_2bc27_row8_col1,#T_2bc27_row8_col2,#T_2bc27_row8_col3,#T_2bc27_row8_col4,#T_2bc27_row8_col5,#T_2bc27_row8_col6,#T_2bc27_row8_col7,#T_2bc27_row8_col8,#T_2bc27_row9_col0,#T_2bc27_row9_col1,#T_2bc27_row9_col2,#T_2bc27_row9_col3,#T_2bc27_row9_col4,#T_2bc27_row9_col5,#T_2bc27_row9_col6,#T_2bc27_row9_col7,#T_2bc27_row9_col8,#T_2bc27_row10_col0,#T_2bc27_row10_col1,#T_2bc27_row10_col2,#T_2bc27_row10_col3,#T_2bc27_row10_col4,#T_2bc27_row10_col5,#T_2bc27_row10_col6,#T_2bc27_row10_col7,#T_2bc27_row10_col8,#T_2bc27_row11_col0,#T_2bc27_row11_col1,#T_2bc27_row11_col2,#T_2bc27_row11_col3,#T_2bc27_row11_col4,#T_2bc27_row11_col5,#T_2bc27_row11_col6,#T_2bc27_row11_col7,#T_2bc27_row11_col8,#T_2bc27_row12_col0,#T_2bc27_row12_col1,#T_2bc27_row12_col2,#T_2bc27_row12_col3,#T_2bc27_row12_col4,#T_2bc27_row12_col5,#T_2bc27_row12_col6,#T_2bc27_row12_col7,#T_2bc27_row12_col8,#T_2bc27_row13_col0,#T_2bc27_row13_col1,#T_2bc27_row13_col2,#T_2bc27_row13_col3,#T_2bc27_row13_col4,#T_2bc27_row13_col5,#T_2bc27_row13_col6,#T_2bc27_row13_col7,#T_2bc27_row13_col8,#T_2bc27_row14_col0,#T_2bc27_row14_col1,#T_2bc27_row14_col2,#T_2bc27_row14_col3,#T_2bc27_row14_col4,#T_2bc27_row14_col5,#T_2bc27_row14_col6,#T_2bc27_row14_col7,#T_2bc27_row14_col8,#T_2bc27_row15_col0,#T_2bc27_row15_col1,#T_2bc27_row15_col2,#T_2bc27_row15_col3,#T_2bc27_row15_col4,#T_2bc27_row15_col5,#T_2bc27_row15_col6,#T_2bc27_row15_col7,#T_2bc27_row15_col8,#T_2bc27_row16_col0,#T_2bc27_row16_col1,#T_2bc27_row16_col2,#T_2bc27_row16_col3,#T_2bc27_row16_col4,#T_2bc27_row16_col5,#T_2bc27_row16_col6,#T_2bc27_row16_col7,#T_2bc27_row16_col8,#T_2bc27_row17_col0,#T_2bc27_row17_col1,#T_2bc27_row17_col2,#T_2bc27_row17_col3,#T_2bc27_row17_col4,#T_2bc27_row17_col5,#T_2bc27_row17_col6,#T_2bc27_row17_col7,#T_2bc27_row17_col8,#T_2bc27_row18_col0,#T_2bc27_row18_col1,#T_2bc27_row18_col2,#T_2bc27_row18_col3,#T_2bc27_row18_col4,#T_2bc27_row18_col5,#T_2bc27_row18_col6,#T_2bc27_row18_col7,#T_2bc27_row18_col8,#T_2bc27_row19_col0,#T_2bc27_row19_col1,#T_2bc27_row19_col2,#T_2bc27_row19_col3,#T_2bc27_row19_col4,#T_2bc27_row19_col5,#T_2bc27_row19_col6,#T_2bc27_row19_col7,#T_2bc27_row19_col8,#T_2bc27_row20_col0,#T_2bc27_row20_col1,#T_2bc27_row20_col2,#T_2bc27_row20_col3,#T_2bc27_row20_col4,#T_2bc27_row20_col5,#T_2bc27_row20_col6,#T_2bc27_row20_col7,#T_2bc27_row20_col8,#T_2bc27_row21_col0,#T_2bc27_row21_col1,#T_2bc27_row21_col2,#T_2bc27_row21_col3,#T_2bc27_row21_col4,#T_2bc27_row21_col5,#T_2bc27_row21_col6,#T_2bc27_row21_col7,#T_2bc27_row21_col8,#T_2bc27_row22_col0,#T_2bc27_row22_col1,#T_2bc27_row22_col2,#T_2bc27_row22_col3,#T_2bc27_row22_col4,#T_2bc27_row22_col5,#T_2bc27_r ...
#                     Column Data Type Missing Values Missing % Unique Values  \
# 0            x_tackler|min   float64              0     0.00%          6596
# 1            x_tackler|max   float64              0     0.00%          6599
# 2           x_tackler|mean   float64              0     0.00%         11961
# 3            x_tackler|std   float64              0     0.00%         11974
# 4           x_tackler|skew   float64              0     0.00%         11974
# ..                     ...       ...            ...       ...           ...
# 221    ballcarrier_y_range   float64              0     0.00%          5195
# 222    ballcarrier_s_range   float64              0     0.00%          2307
# 223    ballcarrier_a_range   float64              0     0.00%          1730
# 224    o_range_ballcarrier   float64              0     0.00%          8980
# 225  dir_range_ballcarrier   float64              0     0.00%          8946
#
#           Min         Max        Mean      Median
# 0    4.590000  109.400000   57.635908   58.135000
# 1    9.320000  119.970000   63.393949   64.085000
# 2    7.585000  111.900625   60.511115   60.992542
# 3    0.032808   26.635287    1.919744    1.481959
# 4   -2.267549    2.825899    0.005834   -0.002717
# ..        ...         ...         ...         ...
# 221  0.070000   46.220000   10.471810    8.230000
# 222  0.237744    9.875520    4.705704    4.745736
# 223  0.411480   11.503152    4.278417    4.306824
# 224  0.000000  359.770000  220.065176  213.580000
# 225  1.710000  359.970000  179.201549  140.510000
#
# [226 rows x 9 columns]

# %%
# 将Cleaned_Data_num中的所有NaN值替换为0
Cleaned_Data_num = Cleaned_Data_num.fillna(0)
generate_summary_table(Cleaned_Data_num)
# Out:
# <style  type="text/css" >
# #T_777ed_row0_col0,#T_777ed_row0_col1,#T_777ed_row0_col2,#T_777ed_row0_col3,#T_777ed_row0_col4,#T_777ed_row0_col5,#T_777ed_row0_col6,#T_777ed_row0_col7,#T_777ed_row0_col8,#T_777ed_row1_col0,#T_777ed_row1_col1,#T_777ed_row1_col2,#T_777ed_row1_col3,#T_777ed_row1_col4,#T_777ed_row1_col5,#T_777ed_row1_col6,#T_777ed_row1_col7,#T_777ed_row1_col8,#T_777ed_row2_col0,#T_777ed_row2_col1,#T_777ed_row2_col2,#T_777ed_row2_col3,#T_777ed_row2_col4,#T_777ed_row2_col5,#T_777ed_row2_col6,#T_777ed_row2_col7,#T_777ed_row2_col8,#T_777ed_row3_col0,#T_777ed_row3_col1,#T_777ed_row3_col2,#T_777ed_row3_col3,#T_777ed_row3_col4,#T_777ed_row3_col5,#T_777ed_row3_col6,#T_777ed_row3_col7,#T_777ed_row3_col8,#T_777ed_row4_col0,#T_777ed_row4_col1,#T_777ed_row4_col2,#T_777ed_row4_col3,#T_777ed_row4_col4,#T_777ed_row4_col5,#T_777ed_row4_col6,#T_777ed_row4_col7,#T_777ed_row4_col8,#T_777ed_row5_col0,#T_777ed_row5_col1,#T_777ed_row5_col2,#T_777ed_row5_col3,#T_777ed_row5_col4,#T_777ed_row5_col5,#T_777ed_row5_col6,#T_777ed_row5_col7,#T_777ed_row5_col8,#T_777ed_row6_col0,#T_777ed_row6_col1,#T_777ed_row6_col2,#T_777ed_row6_col3,#T_777ed_row6_col4,#T_777ed_row6_col5,#T_777ed_row6_col6,#T_777ed_row6_col7,#T_777ed_row6_col8,#T_777ed_row7_col0,#T_777ed_row7_col1,#T_777ed_row7_col2,#T_777ed_row7_col3,#T_777ed_row7_col4,#T_777ed_row7_col5,#T_777ed_row7_col6,#T_777ed_row7_col7,#T_777ed_row7_col8,#T_777ed_row8_col0,#T_777ed_row8_col1,#T_777ed_row8_col2,#T_777ed_row8_col3,#T_777ed_row8_col4,#T_777ed_row8_col5,#T_777ed_row8_col6,#T_777ed_row8_col7,#T_777ed_row8_col8,#T_777ed_row9_col0,#T_777ed_row9_col1,#T_777ed_row9_col2,#T_777ed_row9_col3,#T_777ed_row9_col4,#T_777ed_row9_col5,#T_777ed_row9_col6,#T_777ed_row9_col7,#T_777ed_row9_col8,#T_777ed_row10_col0,#T_777ed_row10_col1,#T_777ed_row10_col2,#T_777ed_row10_col3,#T_777ed_row10_col4,#T_777ed_row10_col5,#T_777ed_row10_col6,#T_777ed_row10_col7,#T_777ed_row10_col8,#T_777ed_row11_col0,#T_777ed_row11_col1,#T_777ed_row11_col2,#T_777ed_row11_col3,#T_777ed_row11_col4,#T_777ed_row11_col5,#T_777ed_row11_col6,#T_777ed_row11_col7,#T_777ed_row11_col8,#T_777ed_row12_col0,#T_777ed_row12_col1,#T_777ed_row12_col2,#T_777ed_row12_col3,#T_777ed_row12_col4,#T_777ed_row12_col5,#T_777ed_row12_col6,#T_777ed_row12_col7,#T_777ed_row12_col8,#T_777ed_row13_col0,#T_777ed_row13_col1,#T_777ed_row13_col2,#T_777ed_row13_col3,#T_777ed_row13_col4,#T_777ed_row13_col5,#T_777ed_row13_col6,#T_777ed_row13_col7,#T_777ed_row13_col8,#T_777ed_row14_col0,#T_777ed_row14_col1,#T_777ed_row14_col2,#T_777ed_row14_col3,#T_777ed_row14_col4,#T_777ed_row14_col5,#T_777ed_row14_col6,#T_777ed_row14_col7,#T_777ed_row14_col8,#T_777ed_row15_col0,#T_777ed_row15_col1,#T_777ed_row15_col2,#T_777ed_row15_col3,#T_777ed_row15_col4,#T_777ed_row15_col5,#T_777ed_row15_col6,#T_777ed_row15_col7,#T_777ed_row15_col8,#T_777ed_row16_col0,#T_777ed_row16_col1,#T_777ed_row16_col2,#T_777ed_row16_col3,#T_777ed_row16_col4,#T_777ed_row16_col5,#T_777ed_row16_col6,#T_777ed_row16_col7,#T_777ed_row16_col8,#T_777ed_row17_col0,#T_777ed_row17_col1,#T_777ed_row17_col2,#T_777ed_row17_col3,#T_777ed_row17_col4,#T_777ed_row17_col5,#T_777ed_row17_col6,#T_777ed_row17_col7,#T_777ed_row17_col8,#T_777ed_row18_col0,#T_777ed_row18_col1,#T_777ed_row18_col2,#T_777ed_row18_col3,#T_777ed_row18_col4,#T_777ed_row18_col5,#T_777ed_row18_col6,#T_777ed_row18_col7,#T_777ed_row18_col8,#T_777ed_row19_col0,#T_777ed_row19_col1,#T_777ed_row19_col2,#T_777ed_row19_col3,#T_777ed_row19_col4,#T_777ed_row19_col5,#T_777ed_row19_col6,#T_777ed_row19_col7,#T_777ed_row19_col8,#T_777ed_row20_col0,#T_777ed_row20_col1,#T_777ed_row20_col2,#T_777ed_row20_col3,#T_777ed_row20_col4,#T_777ed_row20_col5,#T_777ed_row20_col6,#T_777ed_row20_col7,#T_777ed_row20_col8,#T_777ed_row21_col0,#T_777ed_row21_col1,#T_777ed_row21_col2,#T_777ed_row21_col3,#T_777ed_row21_col4,#T_777ed_row21_col5,#T_777ed_row21_col6,#T_777ed_row21_col7,#T_777ed_row21_col8,#T_777ed_row22_col0,#T_777ed_row22_col1,#T_777ed_row22_col2,#T_777ed_row22_col3,#T_777ed_row22_col4,#T_777ed_row22_col5,#T_777ed_r ...
#                     Column Data Type Missing Values Missing % Unique Values  \
# 0            x_tackler|min   float64              0     0.00%          6596
# 1            x_tackler|max   float64              0     0.00%          6599
# 2           x_tackler|mean   float64              0     0.00%         11961
# 3            x_tackler|std   float64              0     0.00%         11974
# 4           x_tackler|skew   float64              0     0.00%         11974
# ..                     ...       ...            ...       ...           ...
# 221    ballcarrier_y_range   float64              0     0.00%          5195
# 222    ballcarrier_s_range   float64              0     0.00%          2307
# 223    ballcarrier_a_range   float64              0     0.00%          1730
# 224    o_range_ballcarrier   float64              0     0.00%          8980
# 225  dir_range_ballcarrier   float64              0     0.00%          8946
#
#           Min         Max        Mean      Median
# 0    4.590000  109.400000   57.635908   58.135000
# 1    9.320000  119.970000   63.393949   64.085000
# 2    7.585000  111.900625   60.511115   60.992542
# 3    0.032808   26.635287    1.919744    1.481959
# 4   -2.267549    2.825899    0.005834   -0.002717
# ..        ...         ...         ...         ...
# 221  0.070000   46.220000   10.471810    8.230000
# 222  0.237744    9.875520    4.705704    4.745736
# 223  0.411480   11.503152    4.278417    4.306824
# 224  0.000000  359.770000  220.065176  213.580000
# 225  1.710000  359.970000  179.201549  140.510000
#
# [226 rows x 9 columns]

# %%
X = Cleaned_Data_num.drop(columns=['tackle_assist_success', 'pff_missedTackle|max', 'tackle|max'])
y = Cleaned_Data_num['tackle_assist_success']

# 使用随机森林回归模型
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X, y)

feature_importances = rf.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# %%
# 按相关性绝对值大小排序
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
final_features_df = feature_importance_df[feature_importance_df['Importance'] >= 0.01]
final_features = final_features_df['Feature'].tolist()

# %%
"""
保存清洗后的数据和最终特征
"""
Cleaned_Data_num.to_csv('../../processed_dataset/Data.csv')
file_path = '../../processed_dataset/final_features.txt'
with open(file_path, 'w') as file:
    for feature in final_features:
        file.write(f'{feature}\n')
